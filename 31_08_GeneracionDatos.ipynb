# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinaenriqz/Optimization-Algorithms-for-Uncertain-Knapsack-Problem/blob/main/31_08_GeneracionDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## cargar datos de github e importar librerias

# %%
# !pip -q install XlsxWriter
# !pip install mip

# !git clone --depth 1 https://github.com/likr/kplib.git

import os
import pandas as pd
from IPython.display import display
from google.colab import files

BASE_DIR = "/content/kplib/00Uncorrelated"
n_values = ["n00050", "n00100", "n00200", "n00500"]
tipo_instancia = "R01000"

instancias = []
for n in n_values:
    ruta = os.path.join(BASE_DIR, n, tipo_instancia)
    if not os.path.isdir(ruta):
        print(f"Ruta no encontrada: {ruta}")
        continue

    archivos = sorted([f for f in os.listdir(ruta) if f.lower().endswith('.kp')])[:60]

    for archivo in archivos:
        ruta_archivo = os.path.join(ruta, archivo)
        try:
            with open(ruta_archivo, 'r') as f:
                lineas = f.readlines()

            num_items = int(lineas[1].strip())
            capacidad = int(lineas[2].strip())
            items = [tuple(map(int, linea.strip().split()))
                     for linea in lineas[4:] if linea.strip()]

            if len(items) != num_items:
                print(f"Advertencia: en {archivo} se esperaban {num_items} ítems pero se leyeron {len(items)}")
                continue

            valores, pesos = zip(*items)
            instancias.append({
                "n": num_items,
                "Capacidad": capacidad,
                "Utilidades": list(valores),
                "Pesos": list(pesos),
                "Archivo": archivo
            })
        except Exception as e:
            print(f"Error al leer {archivo}: {e}")

df_kplib = pd.DataFrame(instancias)
print(f"Instancias cargadas: {df_kplib.shape}")
df_kplib = df_kplib[["Archivo", "n", "Capacidad", "Utilidades", "Pesos"]]
display(df_kplib.head(10))
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.3/172.3 kB 3.3 MB/s eta 0:00:00
# Collecting mip
#   Downloading mip-1.14.2-py3-none-any.whl.metadata (21 kB)
# Collecting cffi==1.15.0 (from mip)
#   Downloading cffi-1.15.0.tar.gz (484 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.1/484.1 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi==1.15.0->mip) (2.22)
# Downloading mip-1.14.2-py3-none-any.whl (15.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 89.6 MB/s eta 0:00:00
# Building wheels for collected packages: cffi
#   Building wheel for cffi (setup.py) ... done
#   Created wheel for cffi: filename=cffi-1.15.0-cp312-cp312-linux_x86_64.whl size=400944 sha256=df65562c55a5fb5864f03ae96b37228652d721d67225b3e96d571ff749430eae
#   Stored in directory: /root/.cache/pip/wheels/b9/d6/15/0950847bf7d74ea5f0380b8b23a1d81b45bdf48488b4b8237a
# Successfully built cffi
# Installing collected packages: cffi, mip
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.17.1
#     Uninstalling cffi-1.17.1:
#       Successfully uninstalled cffi-1.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pygit2 1.18.2 requires cffi>=1.17.0, but you have cffi 1.15.0 which is incompatible.
# rpy2 3.5.17 requires cffi>=1.15.1, but you have cffi 1.15.0 which is incompatible.
# Successfully installed cffi-1.15.0 mip-1.14.2
# Cloning into 'kplib'...
# remote: Enumerating objects: 20320, done.
# remote: Counting objects: 100% (20320/20320), done.
# remote: Compressing objects: 100% (20313/20313), done.
# remote: Total 20320 (delta 7), reused 20319 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (20320/20320), 142.24 MiB | 18.68 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# Updating files: 100% (20801/20801), done.
# Instancias cargadas: (240, 5)
#    Archivo   n  Capacidad                                         Utilidades  \
# 0  s000.kp  50      14778  [845, 758, 421, 259, 512, 405, 784, 304, 477, ...
# 1  s001.kp  50      13598  [135, 848, 764, 256, 496, 450, 652, 789, 94, 2...
# 2  s002.kp  50      13810  [957, 948, 57, 85, 836, 736, 670, 309, 606, 60...
# 3  s003.kp  50      13596  [238, 545, 370, 604, 626, 66, 14, 838, 260, 23...
# 4  s004.kp  50      11618  [237, 104, 397, 155, 67, 402, 918, 801, 766, 2...
# 5  s005.kp  50      11922  [623, 742, 796, 943, 740, 923, 30, 466, 944, 6...
# 6  s006.kp  50      12044  [794, 822, 486, 262, 1, 663, 471, 760, 374, 77...
# 7  s007.kp  50      12828  [324, 151, 651, 73, 536, 366, 58, 508, 38, 434...
# 8  s008.kp  50      10985  [227, 963, 127, 705, 86, 248, 1000, 210, 642, ...
# 9  s009.kp  50      11487  [464, 374, 139, 867, 7, 503, 899, 81, 555, 617...
#
#                                                Pesos
# 0  [804, 448, 81, 321, 508, 933, 110, 552, 707, 5...
# 1  [304, 588, 883, 847, 506, 590, 35, 243, 798, 4...
# 2  [491, 925, 501, 832, 354, 883, 900, 462, 568, ...
# 3  [682, 929, 857, 991, 672, 164, 861, 965, 905, ...
# 4  [281, 535, 472, 343, 998, 196, 413, 203, 633, ...
# 5  [338, 310, 819, 481, 316, 482, 705, 58, 976, 2...
# 6  [881, 526, 117, 663, 313, 197, 484, 139, 210, ...
# 7  [981, 119, 419, 758, 152, 489, 40, 669, 765, 5...
# 8  [703, 950, 844, 504, 198, 151, 529, 510, 72, 9...
# 9  [84, 540, 18, 85, 497, 921, 421, 399, 639, 94,...

# %% [markdown]
# ## sp model

# %%
import time
import numpy as np
import pandas as pd
from mip import Model, CONTINUOUS, MAXIMIZE, CBC, OptimizationStatus


seed = 123
n_smpl = 8
sizes = (50, 100, 200, 500)
# sizes = (50,200)
k = 20



def solve_sp(bar_c, pesos, capacidad, pct_desviacion, split, t, n_smpl, seed=123, verbose=False):
    # --- Normaliza split_A segun t (parche minimo) ---
    # split_A marcador original: [0.0, 0.5, 0.25, 0.25]
    if isinstance(split, (list, tuple)) and len(split) == 4 and np.allclose(split, [0.0, 0.5, 0.25, 0.25]):
        if t == 1:
            split = [1.0, 0.0, 0.0, 0.0]
        elif t == 2:
            split = [0.5, 0.5, 0.0, 0.0]
        elif t == 3:
            split = [0.25, 0.5, 0.25, 0.0]
        else:  # t == 4
            split = [0.0, 0.5, 0.25, 0.25]
    pct_x1, pct_x2, pct_x3, pct_x4 = split
    solver_name = CBC
    time_limit = 360000000
    n = len(bar_c)
    n_x1, n_x2, n_x3 = (int(round(pct_x1*n)), int(round(pct_x2*n)), int(round(pct_x3*n))); n_x4 = n - (n_x1 + n_x2 + n_x3)
    c1, c2, c3, c4 = (np.array(bar_c[:n_x1], float), np.array(bar_c[n_x1:n_x1+n_x2], float), np.array(bar_c[n_x1+n_x2:n_x1+n_x2+n_x3], float), np.array(bar_c[n_x1+n_x2+n_x3:n], float))
    w1, w2, w3, w4 = (np.array(pesos[:n_x1], float), np.array(pesos[n_x1:n_x1+n_x2], float), np.array(pesos[n_x1+n_x2:n_x1+n_x2+n_x3], float), np.array(pesos[n_x1+n_x2+n_x3:n], float))
    rng = np.random.default_rng(seed)
    def _lh(v, delta):
        low, high = v*(1-delta), v*(1+delta)
        return np.minimum(low, high), np.maximum(low, high)
    low2, high2 = _lh(c2, pct_desviacion); U2_base = rng.uniform(low2, high2, size=(n_smpl, n_x2))
    low3, high3 = _lh(c3, pct_desviacion); U3_base = rng.uniform(low3, high3, size=(n_smpl, n_x3))
    low4, high4 = _lh(c4, pct_desviacion); U4_base = rng.uniform(low4, high4, size=(n_smpl, n_x4))
    mu2 = U2_base.mean(axis=0) if U2_base.size else np.array([], float)
    mu3 = U3_base.mean(axis=0) if U3_base.size else np.array([], float)
    mu4 = U4_base.mean(axis=0) if U4_base.size else np.array([], float)
    tile3 = np.tile(mu3, (n_smpl, 1)) if mu3.size else np.zeros((n_smpl, 0), float)
    tile4 = np.tile(mu4, (n_smpl, 1)) if mu4.size else np.zeros((n_smpl, 0), float)
    tile3 = np.tile(c3, (n_smpl, 1)) if c3.size else np.zeros((n_smpl, 0), float)
    tile4 = np.tile(c4, (n_smpl, 1)) if c4.size else np.zeros((n_smpl, 0), float)
    S2 = S3 = S4 = n_smpl
    p2 = p3 = p4 = 1.0 / n_smpl

    # ---------- t == 1 ----------
    if t == 1:
        mean2, mean3, mean4 = mu2, mu3, mu4
        c_mean = np.concatenate([c1, mean2, mean3, mean4]).astype(float)
        w_all = np.concatenate([w1, w2, w3, w4]).astype(float)
        m = Model(sense=MAXIMIZE, solver_name=solver_name); m.max_seconds = time_limit
        x = [m.add_var(var_type=CONTINUOUS, lb=0.0, ub=1.0, name=f"x_{j}") for j in range(n)]
        m.objective = sum(c_mean[j] * x[j] for j in range(n))
        m += (sum(w_all[j] * x[j] for j in range(n)) <= capacidad), "cap"
        t0 = time.perf_counter(); status = m.optimize(); t1 = time.perf_counter()
        solved   = status in (OptimizationStatus.OPTIMAL, OptimizationStatus.FEASIBLE)
        obj_val  = m.objective_value if solved else None
        x_opt    = np.array([var.x for var in x]) if solved else None
        if verbose:
            print(f"[MIP] SP1 | status={status} | obj={obj_val} | vars/cons={m.num_cols}/{m.num_rows} | time={t1-t0:.2f}s")
        assert m.num_cols == n and m.num_rows == 1, f"Vars/Cons esperadas {n}/1, got {m.num_cols}/{m.num_rows}"
        return {"t": 1, "status": str(status), "objective": obj_val, "n_vars": m.num_cols, "n_constrs": m.num_rows, "x": x_opt, "model": m, "split": split}

    # ---------- t == 2 ----------
    elif t == 2:
        c234 = np.concatenate([c2, c3, c4]).astype(float) if (n_x2+n_x3+n_x4)>0 else np.array([], float)
        w2_u = np.concatenate([w2, w3, w4]).astype(float)  if (n_x2+n_x3+n_x4)>0 else np.array([], float)
        U2 = np.concatenate([U2_base, tile3, tile4], axis=1) if c234.size>0 else np.zeros((n_smpl, 0), float)
        n_x2_u = c234.size
        S2 = n_smpl; p2 = 1.0 / n_smpl
        m2 = Model(sense=MAXIMIZE, solver_name=solver_name); m2.max_seconds = time_limit
        x1 = [m2.add_var(var_type=CONTINUOUS, lb=0.0, ub=1.0, name=f"x1_{j}") for j in range(n_x1)]
        x2 = {(s2, j): m2.add_var(var_type=CONTINUOUS, lb=0.0, ub=1.0, name=f"x2_{s2}_{j}") for s2 in range(S2) for j in range(n_x2_u)}
        obj = 0.0
        for j in range(n_x1): obj += c1[j] * x1[j]
        for s2 in range(S2):
            for j in range(n_x2_u):
                obj += (p2 * U2[s2, j]) * x2[(s2, j)]
        m2.objective = obj
        for s2 in range(S2):
            expr = 0.0
            for j in range(n_x1):    expr += w1[j]  * x1[j]
            for j in range(n_x2_u):  expr += w2_u[j] * x2[(s2, j)]
            m2 += (expr <= capacidad), f"cap_{s2}"

        t0 = time.perf_counter(); status = m2.optimize(); t1 = time.perf_counter()
        solved = status in (OptimizationStatus.OPTIMAL, OptimizationStatus.FEASIBLE)
        obj_val = m2.objective_value if solved else None

        if verbose:
            print(f"SP2 | status={status} | obj={obj_val} | vars/cons={m2.num_cols}/{m2.num_rows} | time={t1-t0:.2f}s")
        assert m2.num_cols == n_x1 + n_x2_u*S2, "Conteo de variables inesperado en SP2"
        assert m2.num_rows == S2,               "Conteo de restricciones inesperado en SP2"

        return {"t": 2, "status": str(status), "objective": obj_val, "n_vars": m2.num_cols, "n_constrs": m2.num_rows, "model": m2, "split": split}

    # ---------- t == 3 ----------
    elif t == 3:
        c34 = np.concatenate([c3, c4]).astype(float) if (n_x3+n_x4)>0 else np.array([], float)
        w3_u = np.concatenate([w3, w4]).astype(float)  if (n_x3+n_x4)>0 else np.array([], float)

        # U2 = U2_base (filas = s2), U34 = [ U3_base | tile(mu4) ] (filas = s3)
        U2  = U2_base
        U34 = np.concatenate([U3_base, tile4], axis=1) if c34.size>0 else np.zeros((n_smpl, 0), float)
        n_x3_u = c34.size
        S2 = S3 = n_smpl; p2 = p3 = 1.0 / n_smpl
        m3 = Model(sense=MAXIMIZE, solver_name=solver_name); m3.max_seconds = time_limit
        x1 = [m3.add_var(var_type=CONTINUOUS, lb=0.0, ub=1.0, name=f"x1_{j}") for j in range(n_x1)]
        x2 = {(s2, j): m3.add_var(var_type=CONTINUOUS, lb=0.0, ub=1.0, name=f"x2_{s2}_{j}") for s2 in range(S2) for j in range(n_x2)}
        x3 = {(s2, s3, k): m3.add_var(var_type=CONTINUOUS, lb=0.0, ub=1.0, name=f"x3_{s2}_{s3}_{k}") for s2 in range(S2) for s3 in range(S3) for k in range(n_x3_u)}

        obj = 0.0
        for j in range(n_x1): obj += c1[j] * x1[j]
        for s2 in range(S2):
            for j in range(n_x2):
                obj += (p2 * U2[s2, j]) * x2[(s2, j)]
        for s2 in range(S2):
            for s3 in range(S3):
                for k in range(n_x3_u):
                    obj += (p2 * p3 * U34[s3, k]) * x3[(s2, s3, k)]
        m3.objective = obj

        for s2 in range(S2):
            for s3 in range(S3):
                expr = 0.0
                for j in range(n_x1):    expr += w1[j]   * x1[j]
                for j in range(n_x2):    expr += w2[j]   * x2[(s2, j)]
                for k in range(n_x3_u):  expr += w3_u[k] * x3[(s2, s3, k)]
                m3 += (expr <= capacidad), f"cap_{s2}_{s3}"

        t0 = time.perf_counter(); status = m3.optimize(); t1 = time.perf_counter()
        solved = status in (OptimizationStatus.OPTIMAL, OptimizationStatus.FEASIBLE)
        obj_val = m3.objective_value if solved else None

        if verbose:
            print(f"SP3 | status={status} | obj={obj_val} | vars/cons={m3.num_cols}/{m3.num_rows} | time={t1-t0:.2f}s")
        assert m3.num_cols == n_x1 + n_x2*(S2) + n_x3_u*(S2*S3), "Conteo de variables inesperado en SP3"
        assert m3.num_rows == S2*S3,                              "Conteo de restricciones inesperado en SP3"

        return {"t": 3, "status": str(status), "objective": obj_val, "n_vars": m3.num_cols, "n_constrs": m3.num_rows, "model": m3, "split": split}

    # ---------- t == 4 ----------
    else:
        U2, U3, U4 = U2_base, U3_base, U4_base
        S2 = S3 = S4 = n_smpl
        p2 = p3 = p4 = 1.0 / n_smpl

        m4 = Model(sense=MAXIMIZE, solver_name=solver_name); m4.max_seconds = time_limit
        x1 = [m4.add_var(var_type=CONTINUOUS, lb=0.0, ub=1.0, name=f"x1_{j}") for j in range(n_x1)]
        x2 = {(s2, j): m4.add_var(var_type=CONTINUOUS, lb=0.0, ub=1.0, name=f"x2_{s2}_{j}")
              for s2 in range(S2) for j in range(n_x2)}
        x3 = {(s2, s3, k): m4.add_var(var_type=CONTINUOUS, lb=0.0, ub=1.0, name=f"x3_{s2}_{s3}_{k}")
              for s2 in range(S2) for s3 in range(S3) for k in range(n_x3)}
        x4 = {(s2, s3, s4, h): m4.add_var(var_type=CONTINUOUS, lb=0.0, ub=1.0, name=f"x4_{s2}_{s3}_{s4}_{h}")
              for s2 in range(S2) for s3 in range(S3) for s4 in range(S4) for h in range(n_x4)}
        obj = 0.0
        for j in range(n_x1):
            obj += c1[j] * x1[j]
        for s2 in range(S2):
            for j in range(n_x2):
                obj += (p2 * U2[s2, j]) * x2[(s2, j)]
        for s2 in range(S2):
            for s3 in range(S3):
                for k in range(n_x3):
                    obj += (p2 * p3 * U3[s3, k]) * x3[(s2, s3, k)]
        for s2 in range(S2):
            for s3 in range(S3):
                for s4 in range(S4):
                    for h in range(n_x4):
                        obj += (p2 * p3 * p4 * U4[s4, h]) * x4[(s2, s3, s4, h)]
        m4.objective = obj
        for s2 in range(S2):
            for s3 in range(S3):
                for s4 in range(S4):
                    expr = 0.0
                    for j in range(n_x1): expr += w1[j] * x1[j]
                    for j in range(n_x2): expr += w2[j] * x2[(s2, j)]
                    for k in range(n_x3): expr += w3[k] * x3[(s2, s3, k)]
                    for h in range(n_x4): expr += w4[h] * x4[(s2, s3, s4, h)]
                    m4 += (expr <= capacidad), f"cap_{s2}_{s3}_{s4}"
        t0 = time.perf_counter(); status = m4.optimize(); t1 = time.perf_counter()  # cronometraje
        solved  = status in (OptimizationStatus.OPTIMAL, OptimizationStatus.FEASIBLE)
        obj_val = m4.objective_value if solved else None
        if verbose:
            print(f"SP4 | status={status} | obj={obj_val} | vars/cons={m4.num_cols}/{m4.num_rows} | time={t1-t0:.2f}s")
        exp_vars = n_x1 + n_x2*S2 + n_x3*(S2*S3) + n_x4*(S2*S3*S4)
        exp_cons = S2*S3*S4
        assert m4.num_cols == exp_vars, f"Vars esperadas {exp_vars}, got {m4.num_cols}"
        assert m4.num_rows == exp_cons, f"Cons esperadas {exp_cons}, got {m4.num_rows}"
        return {"t": 4, "status": str(status), "objective": obj_val, "n_vars": m4.num_cols, "n_constrs": m4.num_rows, "model": m4, "split": split }


# PROCESAMIENTO DE LAS INSTANCIAS

# =========================
# EXPERIMENTO (bucle único)
# =========================
filas = []

split_A = [0.00, 0.50, 0.25, 0.25]  # SP1..SP4
split_B = [0.25, 0.75, 0.00, 0.00]  # solo SP2 -> SP2split_75
split_C = [0.50, 0.50, 0.00, 0.00]  # solo SP2 -> SP2split_50  (debe coincidir con SP2)
split_D = [0.75, 0.25, 0.00, 0.00]  # solo SP2 -> SP2split_25

def label_for(t, split_list):
    """Etiqueta coherente con tu semántica; None si no aplica."""
    if split_list == split_A:
        return {1:"SP1", 2:"SP2", 3:"SP3", 4:"SP4"}.get(t, None)
    if t != 2:
        return None  # B,C,D solo para SP2
    if split_list == split_B: return "SP2split_75"
    if split_list == split_C: return "SP2split_50"
    if split_list == split_D: return "SP2split_25"
    return None

for pct_desviacion in (0.1, 0.5, 1.0, 1.5, 2.0):
    for n_target in sizes:
        df_sub = df_kplib[df_kplib["n"] == n_target].head(k)
        for idx, row in df_sub.iterrows():
            bar_c = np.array(row["Utilidades"], float)
            pesos = np.array(row["Pesos"], float)
            cap   = float(row["Capacidad"])
            arc   = row["Archivo"] if "Archivo" in df_kplib.columns else f"idx_{idx}"
            assert bar_c.size == pesos.size, f"Dim mismatch en {arc}"

            # --- Nominal ---
            m_nom = Model(sense=MAXIMIZE, solver_name=CBC)
            x_nom = [m_nom.add_var(var_type=CONTINUOUS, lb=0.0, ub=1.0) for _ in range(len(bar_c))]
            m_nom.objective = sum(bar_c[j]*x_nom[j] for j in range(len(bar_c)))
            m_nom += (sum(pesos[j]*x_nom[j] for j in range(len(bar_c))) <= cap)
            m_nom.optimize()
            filas.append({
                "Archivo": arc, "n": int(row["n"]), "Capacidad": cap, "%Desv": 0.0,
                "t": 0, "split": "nominal", "objective": round(float(m_nom.objective_value), 6),
                "time_s": None, "label": "Nominal"
            })

            # --- SP1..SP4 con split_A + SP2_splits (B/C/D) ---
            for t in (1, 2, 3, 4):
                for split in (split_A, split_B, split_C, split_D):
                    # Respeta semántica: B/C/D solo cuando t=2
                    if split in (split_B, split_C, split_D) and t != 2:
                        continue
                    t0 = time.perf_counter()
                    sol = solve_sp(bar_c, pesos, cap, pct_desviacion, split, t=t,
                                   n_smpl=n_smpl, seed=seed, verbose=True)
                    t1 = time.perf_counter()
                    obj = float(sol["objective"]) if sol["objective"] is not None else np.nan
                    split_str = "-".join(f"{p:.2f}" for p in sol["split"])
                    filas.append({
                        "Archivo": arc, "n": int(row["n"]), "Capacidad": cap, "%Desv": pct_desviacion,
                        "t": t, "split": split_str, "objective": round(obj, 6),
                        "time_s": round(t1 - t0, 6), "label": label_for(t, split)
                    })

# -------------------------------
# CONSTRUCCIÓN DE df_experimento
# -------------------------------
df_long = pd.DataFrame(filas)

# Nominal por instancia (no depende de %Desv)
nominal = (df_long[df_long["label"]=="Nominal"][["Archivo","n","Capacidad","objective"]]
           .drop_duplicates(subset=["Archivo","n","Capacidad"])
           .rename(columns={"objective":"Nominal"}))

# Nos quedamos con filas etiquetadas (SP1, SP2, SP3, SP4, SP2split_25/50/75)

df_long_excel = df_long.to_excel("df_long_pct_desviacion_hasta_2.xlsx")

files.download("df_long_pct_desviacion_hasta_2.xlsx")
# Out:
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=21047.483258928572 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=21044.94759529437 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=21025.35030165557 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=21044.94759529437 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=21053.770057513797 | vars/cons=134/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=21125.478931849808 | vars/cons=1044/64 | time=0.03s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=21037.590624593577 | vars/cons=7624/512 | time=0.78s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=19845.257575757576 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19744.328685559576 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19838.238780623804 | vars/cons=316/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19744.328685559576 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19820.086837303646 | vars/cons=134/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=19847.251865147013 | vars/cons=1044/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=19817.891169745028 | vars/cons=7624/512 | time=0.95s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=20657.83995459705 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20593.66891146709 | vars/cons=225/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20661.013417134476 | vars/cons=316/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20593.66891146709 | vars/cons=225/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20646.106872863522 | vars/cons=134/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=20491.477279648454 | vars/cons=1044/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=20637.99131326417 | vars/cons=7624/512 | time=0.70s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=19837.165720771853 | vars/cons=50/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19829.936522497595 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19795.735456636296 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19829.936522497595 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19805.269461569907 | vars/cons=134/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=19794.87378800201 | vars/cons=1044/64 | time=0.05s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=19784.292902562534 | vars/cons=7624/512 | time=0.70s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=20987.072127139363 | vars/cons=50/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20942.714289518397 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20946.917674419765 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20942.714289518397 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20968.009906783387 | vars/cons=134/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=20972.660056190598 | vars/cons=1044/64 | time=0.05s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=21022.99702762262 | vars/cons=7624/512 | time=0.79s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=19833.996336996337 | vars/cons=50/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19871.444234855277 | vars/cons=225/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19835.135275578545 | vars/cons=316/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19871.444234855277 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19817.140629070513 | vars/cons=134/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=19783.402204870916 | vars/cons=1044/64 | time=0.17s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=19836.493463046205 | vars/cons=7624/512 | time=0.68s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=21442.180428134554 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=21389.903452363065 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=21424.236385046617 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=21389.903452363065 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=21405.892301937787 | vars/cons=134/8 | time=0.00s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=21396.861183868226 | vars/cons=1044/64 | time=0.03s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=21439.748382392743 | vars/cons=7624/512 | time=0.34s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=16795.487804878052 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=16758.232030877316 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=16729.746773367744 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=16758.232030877316 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=16790.024762158046 | vars/cons=134/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=16835.884143771767 | vars/cons=1044/64 | time=0.04s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=16848.950165726474 | vars/cons=7624/512 | time=0.34s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=19458.264534883718 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19403.41657004597 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19370.352899770925 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19403.41657004597 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19455.206751644204 | vars/cons=134/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=19360.846286160115 | vars/cons=1044/64 | time=0.04s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=19446.188906873766 | vars/cons=7624/512 | time=0.26s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=18406.940881763527 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=18373.167900310887 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=18378.018313665918 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=18373.167900310887 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=18417.043215951213 | vars/cons=134/8 | time=0.00s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=18315.295998119975 | vars/cons=1044/64 | time=0.03s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=18412.55223851321 | vars/cons=7624/512 | time=0.25s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=20233.45244215938 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20156.30310041658 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20213.20527567755 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20156.30310041658 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20219.055591269254 | vars/cons=134/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=20215.336598503844 | vars/cons=1044/64 | time=0.03s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=20240.907119029256 | vars/cons=7624/512 | time=0.29s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=20420.433889602053 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20314.220566374195 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20356.738931252337 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20314.220566374195 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20399.732742116637 | vars/cons=134/8 | time=0.00s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=20394.863686180823 | vars/cons=1044/64 | time=0.03s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=20366.198250637735 | vars/cons=7624/512 | time=0.31s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=18773.522478736333 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=18655.45260992143 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=18700.894225528125 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=18655.45260992143 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=18744.08653372821 | vars/cons=134/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=18698.085891096467 | vars/cons=1044/64 | time=0.03s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=18703.964570478052 | vars/cons=7624/512 | time=0.26s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=20104.0 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20027.268221201244 | vars/cons=225/8 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20073.487027206145 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20027.268221201244 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=20086.44781656742 | vars/cons=134/8 | time=0.00s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=20057.39712221041 | vars/cons=1044/64 | time=0.03s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=19918.73123847161 | vars/cons=7624/512 | time=0.42s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=19118.77659574468 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19108.670896307 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19076.984598088053 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19108.670896307 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19094.025107228008 | vars/cons=134/8 | time=0.00s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=19129.383461996524 | vars/cons=1044/64 | time=0.07s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=19097.42017421754 | vars/cons=7624/512 | time=0.67s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=22437.830508474577 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=22373.245549461008 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=22330.292448211803 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=22373.245549461008 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=22423.901814812994 | vars/cons=134/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=22417.267912793755 | vars/cons=1044/64 | time=0.04s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=22533.013841214422 | vars/cons=7624/512 | time=0.21s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=19274.786644951142 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19276.469775268648 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19223.422871919596 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19276.469775268648 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19251.49244246218 | vars/cons=134/8 | time=0.00s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=19171.12401541164 | vars/cons=1044/64 | time=0.02s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=19194.692263946694 | vars/cons=7624/512 | time=0.21s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=23079.30425299891 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=23099.052394558195 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=22976.350602379975 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=23099.052394558195 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=23058.556060930834 | vars/cons=134/8 | time=0.00s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=22936.969666797948 | vars/cons=1044/64 | time=0.02s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=22983.71949983243 | vars/cons=7624/512 | time=0.24s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=19125.43358946213 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19127.156342262784 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19111.352684856985 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19127.156342262784 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=19142.826012583257 | vars/cons=134/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=19134.754605127684 | vars/cons=1044/64 | time=0.03s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=19065.008962000975 | vars/cons=7624/512 | time=0.29s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=18232.536060279872 | vars/cons=50/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=18219.208083710935 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=18214.278125408 | vars/cons=316/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=18219.208083710935 | vars/cons=225/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=18227.31234430914 | vars/cons=134/8 | time=0.00s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=18164.32792115062 | vars/cons=1044/64 | time=0.03s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=18214.18704029663 | vars/cons=7624/512 | time=0.28s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=46587.73852721451 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=46619.46397744824 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=46715.6468392578 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=46619.46397744824 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=46562.27618422779 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=46754.56452864222 | vars/cons=2025/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=46688.7754096118 | vars/cons=14800/512 | time=0.69s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=41070.35 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=40966.76895008033 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=41228.45260855564 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=40966.76895008033 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=41031.76026957092 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=41232.6714300225 | vars/cons=2025/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=41035.48304129297 | vars/cons=14800/512 | time=0.94s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=45586.98269230769 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=45585.74848342786 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=45776.27927953989 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=45585.74848342786 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=45521.097741284204 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=45725.02069677151 | vars/cons=2025/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=45551.870614083164 | vars/cons=14800/512 | time=0.58s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=43512.23854660347 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=43493.07749528067 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=43660.040777026654 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=43493.07749528067 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=43521.37677811448 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=43590.18258235367 | vars/cons=2025/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=43504.239653462144 | vars/cons=14800/512 | time=0.58s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=38899.04313725491 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38860.09179984508 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38896.115347732826 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38860.09179984508 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38857.706247972324 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=38851.46159002104 | vars/cons=2025/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=38889.22660405061 | vars/cons=14800/512 | time=0.60s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=42313.688421052626 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=42319.40832019518 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=42409.673203160106 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=42319.40832019518 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=42351.29891157249 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=42309.877866118666 | vars/cons=2025/64 | time=0.05s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=42472.871654119255 | vars/cons=14800/512 | time=0.56s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=41535.107049608356 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=41506.00552559213 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=41521.29265475995 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=41506.00552559213 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=41594.28486755211 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=41474.03971286662 | vars/cons=2025/64 | time=0.07s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=41557.16836487911 | vars/cons=14800/512 | time=0.55s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=38343.51234567902 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38347.58088420813 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38455.14002610849 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38347.58088420813 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38363.93329373521 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=38357.06331754945 | vars/cons=2025/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=38342.30492494853 | vars/cons=14800/512 | time=0.73s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=37213.74022346368 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37166.19588460894 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37273.818155219335 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37166.19588460894 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37145.52359904115 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=37189.060185391594 | vars/cons=2025/64 | time=0.07s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=37225.2331235332 | vars/cons=14800/512 | time=0.74s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=36492.68341708542 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=36528.28528837539 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=36607.24796275884 | vars/cons=625/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=36528.28528837539 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=36458.54377649728 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=36602.151678829985 | vars/cons=2025/64 | time=0.10s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=36551.31983717283 | vars/cons=14800/512 | time=0.65s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=39747.32628398792 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=39728.96079151171 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=39809.680112225826 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=39728.96079151171 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=39650.27924422641 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=39788.66548934569 | vars/cons=2025/64 | time=0.07s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=39752.803537669795 | vars/cons=14800/512 | time=0.68s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=38652.36523929471 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38679.49852691956 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38880.65149163566 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38679.49852691956 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38656.377691036345 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=38726.80614899068 | vars/cons=2025/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=38697.224409503826 | vars/cons=14800/512 | time=0.62s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=37455.13807531381 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37462.9084996046 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37497.37807959789 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37462.9084996046 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37407.18414720553 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=37493.19734497034 | vars/cons=2025/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=37466.69179114418 | vars/cons=14800/512 | time=0.96s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=40288.058139534885 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=40253.11785014057 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=40358.62223518798 | vars/cons=625/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=40253.11785014057 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=40279.27837457825 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=40328.85581010643 | vars/cons=2025/64 | time=0.10s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=40352.983612259726 | vars/cons=14800/512 | time=0.59s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=37316.05677655678 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37375.38739273966 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37406.99987498785 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37375.38739273966 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37254.62417547723 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=37368.09264203431 | vars/cons=2025/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=37319.577097975874 | vars/cons=14800/512 | time=0.04s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=42363.103658536595 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=42283.70759886701 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=42417.83561976736 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=42283.70759886701 | vars/cons=450/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=42312.8959270425 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=42413.57410043006 | vars/cons=2025/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=42346.78934004391 | vars/cons=14800/512 | time=0.64s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=36401.54246885617 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=36375.89266529118 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=36459.59075854136 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=36375.89266529118 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=36397.530508407 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=36507.95385579549 | vars/cons=2025/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=36397.685426052056 | vars/cons=14800/512 | time=1.00s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=43757.14558472554 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=43589.84320843993 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=43773.21433746399 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=43589.84320843993 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=43625.84922631879 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=43887.43078608892 | vars/cons=2025/64 | time=0.06s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=43726.18400104602 | vars/cons=14800/512 | time=0.60s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=39062.972860125265 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38895.05339494693 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=39120.40796863546 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38895.05339494693 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=38990.19583108153 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=39195.816154180786 | vars/cons=2025/64 | time=0.05s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=39103.42893950418 | vars/cons=14800/512 | time=0.57s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=37615.8266384778 | vars/cons=100/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37504.953372383054 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37679.922909238565 | vars/cons=625/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37504.953372383054 | vars/cons=450/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=37582.281762106024 | vars/cons=275/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=37642.38109014226 | vars/cons=2025/64 | time=0.05s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=37535.167034588914 | vars/cons=14800/512 | time=0.51s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=84360.4957264957 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=84367.55041352955 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=84520.87249176379 | vars/cons=1250/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=84367.55041352955 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=84265.59778548351 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=84506.73120791645 | vars/cons=4050/64 | time=0.19s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=84563.13673800335 | vars/cons=29600/512 | time=1.42s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=78965.28426395939 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=79034.20356773052 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=79143.24733081885 | vars/cons=1250/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=79034.20356773052 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78962.8042486859 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=79169.83185675266 | vars/cons=4050/64 | time=0.13s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=78733.41124022116 | vars/cons=29600/512 | time=1.77s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=80321.07549668875 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=80379.67808386449 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=80365.53259415606 | vars/cons=1250/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=80379.67808386449 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=80331.26543120448 | vars/cons=550/8 | time=0.02s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=80393.30950794707 | vars/cons=4050/64 | time=0.15s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=80289.77047233691 | vars/cons=29600/512 | time=1.47s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=81717.02791878172 | vars/cons=200/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81758.46861203782 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81819.90056174264 | vars/cons=1250/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81758.46861203782 | vars/cons=900/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81673.46755999037 | vars/cons=550/8 | time=0.02s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=81874.11987922428 | vars/cons=4050/64 | time=0.17s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=81585.41376556919 | vars/cons=29600/512 | time=1.60s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=84067.27816411683 | vars/cons=200/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=83926.37611281114 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=84278.1525304179 | vars/cons=1250/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=83926.37611281114 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=84030.71522948892 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=84109.63124364732 | vars/cons=4050/64 | time=0.15s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=84120.77945918812 | vars/cons=29600/512 | time=2.19s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=86056.09803921565 | vars/cons=200/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=86032.20431292047 | vars/cons=900/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=86063.40631357256 | vars/cons=1250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=86032.20431292047 | vars/cons=900/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=85992.40480003305 | vars/cons=550/8 | time=0.02s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=86183.97004803107 | vars/cons=4050/64 | time=0.14s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=86250.39285432086 | vars/cons=29600/512 | time=1.79s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=85522.84738955823 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=85428.36699661959 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=85557.05836536468 | vars/cons=1250/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=85428.36699661959 | vars/cons=900/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=85352.11042601452 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=85581.23522644716 | vars/cons=4050/64 | time=0.22s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=85507.10108748342 | vars/cons=29600/512 | time=1.34s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=78553.50849377122 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78517.97959612854 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78779.2247819152 | vars/cons=1250/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78517.97959612854 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78408.84697194079 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=78764.8895177549 | vars/cons=4050/64 | time=0.14s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=78448.68519626439 | vars/cons=29600/512 | time=1.31s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=78106.592 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78107.1195874255 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78165.58867734729 | vars/cons=1250/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78107.1195874255 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78095.38626736807 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=78218.9652612712 | vars/cons=4050/64 | time=0.14s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=78053.82254455567 | vars/cons=29600/512 | time=1.57s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=78532.76923076923 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78547.68917916098 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78577.68174552353 | vars/cons=1250/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78547.68917916098 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78520.36258225393 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=78658.13269465663 | vars/cons=4050/64 | time=0.13s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=78503.52278011845 | vars/cons=29600/512 | time=1.44s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=80496.23584905663 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=80467.76155549551 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=80369.36183808884 | vars/cons=1250/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=80467.76155549551 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=80334.38161416553 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=80521.82810803795 | vars/cons=4050/64 | time=0.14s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=80382.43779592718 | vars/cons=29600/512 | time=2.49s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=81555.43888070693 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81496.8561612022 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81593.80109578013 | vars/cons=1250/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81496.8561612022 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81595.3783645421 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=81612.8736028042 | vars/cons=4050/64 | time=0.15s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=81552.9538422759 | vars/cons=29600/512 | time=1.51s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=78862.84678362573 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78878.82424032161 | vars/cons=900/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78851.30590870717 | vars/cons=1250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78878.82424032161 | vars/cons=900/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78740.89551196185 | vars/cons=550/8 | time=0.02s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=78918.22367064607 | vars/cons=4050/64 | time=0.25s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=78736.0267640189 | vars/cons=29600/512 | time=1.44s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=76738.87121212123 | vars/cons=200/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=76786.26430825792 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=76729.4487000863 | vars/cons=1250/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=76786.26430825792 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=76721.54484127555 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=76744.51878895302 | vars/cons=4050/64 | time=0.12s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=76747.47525707385 | vars/cons=29600/512 | time=1.47s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=81853.73703256935 | vars/cons=200/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81930.99909045911 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=82009.986666263 | vars/cons=1250/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81930.99909045911 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81769.50156273691 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=81935.5682551948 | vars/cons=4050/64 | time=0.11s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=81902.40032188904 | vars/cons=29600/512 | time=1.37s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=84048.39924906133 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=84189.20910621327 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=84163.71010525624 | vars/cons=1250/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=84189.20910621327 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=84095.77910837598 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=84059.29519711499 | vars/cons=4050/64 | time=0.17s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=84220.83295192473 | vars/cons=29600/512 | time=1.45s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=78022.18987341772 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78041.81013682859 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78145.98150106086 | vars/cons=1250/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78041.81013682859 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=78006.17285799682 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=78079.07341671735 | vars/cons=4050/64 | time=0.12s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=77977.08409371237 | vars/cons=29600/512 | time=2.83s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=83183.20322580643 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=83189.6891293888 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=83255.58595881163 | vars/cons=1250/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=83189.6891293888 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=83165.31966162722 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=83220.63494091886 | vars/cons=4050/64 | time=0.14s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=83254.27005813425 | vars/cons=29600/512 | time=1.42s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=80932.65536723165 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81057.85239354755 | vars/cons=900/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81049.56855176677 | vars/cons=1250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=81057.85239354755 | vars/cons=900/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=80857.43080006033 | vars/cons=550/8 | time=0.02s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=81010.85865459584 | vars/cons=4050/64 | time=0.27s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=80873.27034389463 | vars/cons=29600/512 | time=1.41s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=74415.52121212124 | vars/cons=200/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=74415.37980567194 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=74387.16285824582 | vars/cons=1250/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=74415.37980567194 | vars/cons=900/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=74320.37718443172 | vars/cons=550/8 | time=0.02s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=74370.12469686911 | vars/cons=4050/64 | time=0.14s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=74131.59089778228 | vars/cons=29600/512 | time=1.45s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=207992.838 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=207937.86113166777 | vars/cons=2250/8 | time=0.07s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=207972.64504126794 | vars/cons=3125/8 | time=0.08s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=207937.86113166777 | vars/cons=2250/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=207962.92100338708 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=207711.72060090734 | vars/cons=10125/64 | time=0.40s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=207875.4326100019 | vars/cons=74000/512 | time=5.54s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=202855.78242677829 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=202722.39364583505 | vars/cons=2250/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=202701.85676037928 | vars/cons=3125/8 | time=0.10s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=202722.39364583505 | vars/cons=2250/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=202947.498151677 | vars/cons=1375/8 | time=0.05s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=202625.14969536645 | vars/cons=10125/64 | time=0.49s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=202843.83419899046 | vars/cons=74000/512 | time=5.65s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=201381.81101376718 | vars/cons=500/1 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=201469.31497371843 | vars/cons=2250/8 | time=0.10s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=201252.44554599212 | vars/cons=3125/8 | time=0.13s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=201469.31497371843 | vars/cons=2250/8 | time=0.10s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=201598.44528036434 | vars/cons=1375/8 | time=0.06s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=201233.4475161648 | vars/cons=10125/64 | time=0.48s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=201493.87706790655 | vars/cons=74000/512 | time=7.01s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=203018.52769385697 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=203144.45080672784 | vars/cons=2250/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=203195.70440615638 | vars/cons=3125/8 | time=0.09s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=203144.45080672784 | vars/cons=2250/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=203127.71716085763 | vars/cons=1375/8 | time=0.04s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=203234.39424008128 | vars/cons=10125/64 | time=0.44s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=203005.03490731557 | vars/cons=74000/512 | time=5.35s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=211168.49372384936 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=211023.63515011148 | vars/cons=2250/8 | time=0.07s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=210982.10032857262 | vars/cons=3125/8 | time=0.09s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=211023.63515011148 | vars/cons=2250/8 | time=0.08s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=211359.41681501296 | vars/cons=1375/8 | time=0.04s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=210687.0570275456 | vars/cons=10125/64 | time=0.45s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=211051.12278942126 | vars/cons=74000/512 | time=5.54s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=202425.2083958021 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=202438.15042319815 | vars/cons=2250/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=202211.67754086855 | vars/cons=3125/8 | time=0.09s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=202438.15042319815 | vars/cons=2250/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=202547.94658595373 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=202420.05926198926 | vars/cons=10125/64 | time=0.45s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=202246.66319040634 | vars/cons=74000/512 | time=4.91s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=205765.38651102467 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=205723.3890839809 | vars/cons=2250/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=205729.17294034944 | vars/cons=3125/8 | time=0.09s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=205723.3890839809 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=205936.92811779375 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=205696.13172369535 | vars/cons=10125/64 | time=0.69s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=205727.24762938148 | vars/cons=74000/512 | time=4.99s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=197490.64885496185 | vars/cons=500/1 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=197603.48229039562 | vars/cons=2250/8 | time=0.08s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=197506.25642224238 | vars/cons=3125/8 | time=0.12s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=197603.48229039562 | vars/cons=2250/8 | time=0.09s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=197516.40723730726 | vars/cons=1375/8 | time=0.06s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=197466.82233442194 | vars/cons=10125/64 | time=0.46s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=197491.33931174685 | vars/cons=74000/512 | time=5.86s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=206348.56369426748 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=206424.02688116656 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=206325.44115008414 | vars/cons=3125/8 | time=0.09s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=206424.02688116656 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=206433.69517633252 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=206090.69975360864 | vars/cons=10125/64 | time=0.47s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=206303.94560728178 | vars/cons=74000/512 | time=6.19s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=199203.88235294117 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=199055.87832989762 | vars/cons=2250/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=198845.68509098017 | vars/cons=3125/8 | time=0.08s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=199055.87832989762 | vars/cons=2250/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=199167.68444077385 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=198882.94508194953 | vars/cons=10125/64 | time=0.46s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=198941.175147263 | vars/cons=74000/512 | time=4.92s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=200597.43066516347 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=200858.8936263415 | vars/cons=2250/8 | time=0.08s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=200590.41568810522 | vars/cons=3125/8 | time=0.09s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=200858.8936263415 | vars/cons=2250/8 | time=0.06s
# ...
# SP3 | status=OptimizationStatus.OPTIMAL | obj=95389.64521180118 | vars/cons=4050/64 | time=0.14s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=98816.88356903083 | vars/cons=29600/512 | time=0.07s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=83183.20322580643 | vars/cons=200/1 | time=0.00s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=95923.07987644714 | vars/cons=900/8 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=103260.07213963591 | vars/cons=1250/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=95923.07987644714 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=88813.10909364505 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=102746.19882875339 | vars/cons=4050/64 | time=0.11s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=108302.68093059503 | vars/cons=29600/512 | time=0.06s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=80932.65536723165 | vars/cons=200/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=96761.98042363758 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=103703.62132196917 | vars/cons=1250/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=96761.98042363758 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=86878.21342726209 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=102670.63643736218 | vars/cons=4050/64 | time=0.12s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=104841.10471080535 | vars/cons=29600/512 | time=0.10s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=74415.52121212124 | vars/cons=200/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=86329.55163665197 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=91138.55810621053 | vars/cons=1250/8 | time=0.03s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=86329.55163665197 | vars/cons=900/8 | time=0.02s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=79043.16615823483 | vars/cons=550/8 | time=0.01s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=91195.52810488157 | vars/cons=4050/64 | time=0.11s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=92781.04227605567 | vars/cons=29600/512 | time=0.06s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=207992.838 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=240857.19133214446 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=256920.82816458956 | vars/cons=3125/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=240857.19133214446 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=225093.10405424752 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=252487.05577333065 | vars/cons=10125/64 | time=0.42s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=271761.6783451616 | vars/cons=74000/512 | time=4.25s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=202855.78242677829 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=233606.1092849344 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=248553.70981115566 | vars/cons=3125/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=233606.1092849344 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=221190.49535958187 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=247153.71009322128 | vars/cons=10125/64 | time=0.32s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=263959.55093973654 | vars/cons=74000/512 | time=3.55s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=201381.81101376718 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=237371.4270207813 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=249853.7376540923 | vars/cons=3125/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=237371.4270207813 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=221018.06795517876 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=248823.71292751597 | vars/cons=10125/64 | time=0.30s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=267340.7203578691 | vars/cons=74000/512 | time=3.60s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=203018.52769385697 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=237973.80427090757 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=253094.2092502947 | vars/cons=3125/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=237973.80427090757 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=220937.45876565957 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=253380.99033264443 | vars/cons=10125/64 | time=0.37s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=265184.15860701806 | vars/cons=74000/512 | time=3.43s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=211168.49372384936 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=243676.6517495619 | vars/cons=2250/8 | time=0.07s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=260233.57117213728 | vars/cons=3125/8 | time=0.08s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=243676.6517495619 | vars/cons=2250/8 | time=0.07s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=231181.83161019656 | vars/cons=1375/8 | time=0.04s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=255402.77452069544 | vars/cons=10125/64 | time=0.32s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=274702.4971695181 | vars/cons=74000/512 | time=4.19s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=202425.2083958021 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=232528.3572217241 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=246936.41284877204 | vars/cons=3125/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=232528.3572217241 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=217457.77739958809 | vars/cons=1375/8 | time=0.04s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=248781.78872433447 | vars/cons=10125/64 | time=0.39s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=260675.87900944005 | vars/cons=74000/512 | time=0.16s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=205765.38651102467 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=236542.55889077557 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=249926.40024059266 | vars/cons=3125/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=236542.55889077557 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=224185.65472379743 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=250284.24430936607 | vars/cons=10125/64 | time=0.34s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=267134.9153933648 | vars/cons=74000/512 | time=0.16s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=197490.64885496185 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=228115.4442841441 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=242274.67803983978 | vars/cons=3125/8 | time=0.07s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=228115.4442841441 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=212971.65720750106 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=242022.40307542332 | vars/cons=10125/64 | time=0.34s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=254768.0260166969 | vars/cons=74000/512 | time=0.17s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=206348.56369426748 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=239511.74579990815 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=255447.64714285306 | vars/cons=3125/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=239511.74579990815 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=223576.7853822127 | vars/cons=1375/8 | time=0.04s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=253459.9811373343 | vars/cons=10125/64 | time=0.31s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=273485.8053242006 | vars/cons=74000/512 | time=3.48s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=199203.88235294117 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=228246.62063421868 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=237427.49418449504 | vars/cons=3125/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=228246.62063421868 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=214737.1774855291 | vars/cons=1375/8 | time=0.02s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=239232.4921298343 | vars/cons=10125/64 | time=0.34s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=253198.2334865073 | vars/cons=74000/512 | time=0.16s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=200597.43066516347 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=236671.67358895586 | vars/cons=2250/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=248648.92874509006 | vars/cons=3125/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=236671.67358895586 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=221895.96059981172 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=247614.380520672 | vars/cons=10125/64 | time=0.37s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=261929.01525035265 | vars/cons=74000/512 | time=3.47s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=205456.9407665505 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=237104.75490564096 | vars/cons=2250/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=255585.00925061657 | vars/cons=3125/8 | time=0.07s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=237104.75490564096 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=222657.1430120242 | vars/cons=1375/8 | time=0.04s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=254096.19269102736 | vars/cons=10125/64 | time=0.32s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=271074.140065105 | vars/cons=74000/512 | time=0.16s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=202109.18957345968 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=236349.91394264053 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=251256.45172207468 | vars/cons=3125/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=236349.91394264053 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=221567.83195735776 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=251786.96299179838 | vars/cons=10125/64 | time=0.36s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=263373.91983618896 | vars/cons=74000/512 | time=0.16s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=200457.11913357401 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=232466.68266523624 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=241184.83924278957 | vars/cons=3125/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=232466.68266523624 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=217981.05153911063 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=241984.9010578055 | vars/cons=10125/64 | time=0.32s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=252190.80629587462 | vars/cons=74000/512 | time=0.18s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=204591.8691275167 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=235071.22404711015 | vars/cons=2250/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=250148.1480071641 | vars/cons=3125/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=235071.22404711015 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=221660.13321861206 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=250480.46653065208 | vars/cons=10125/64 | time=0.30s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=265448.64900005056 | vars/cons=74000/512 | time=3.68s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=212142.9656964657 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=247079.01917931446 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=262561.18039293773 | vars/cons=3125/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=247079.01917931446 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=230299.1845573828 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=266757.6011511851 | vars/cons=10125/64 | time=0.46s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=280906.69704735064 | vars/cons=74000/512 | time=0.16s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=195332.57600000003 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=224423.32341834457 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=236535.61582877353 | vars/cons=3125/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=224423.32341834457 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=211174.25943835563 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=234106.90153443048 | vars/cons=10125/64 | time=0.50s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=255108.2808751191 | vars/cons=74000/512 | time=0.16s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=197892.10532030402 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=226007.19798313573 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=241350.1536428144 | vars/cons=3125/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=226007.19798313573 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=212361.30066228923 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=244730.62768236798 | vars/cons=10125/64 | time=0.49s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=254563.3466808972 | vars/cons=74000/512 | time=0.18s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=204385.5 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=235231.71382231553 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=251471.3133316769 | vars/cons=3125/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=235231.71382231553 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=222056.23429921293 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=248698.15775852365 | vars/cons=10125/64 | time=0.55s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=269204.7303878367 | vars/cons=74000/512 | time=0.16s
# [MIP] SP1 | status=OptimizationStatus.OPTIMAL | obj=204088.1433506045 | vars/cons=500/1 | time=0.01s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=235736.99914629772 | vars/cons=2250/8 | time=0.05s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=248696.4022246205 | vars/cons=3125/8 | time=0.06s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=235736.99914629772 | vars/cons=2250/8 | time=0.04s
# SP2 | status=OptimizationStatus.OPTIMAL | obj=223802.61336553097 | vars/cons=1375/8 | time=0.03s
# SP3 | status=OptimizationStatus.OPTIMAL | obj=250671.12877942264 | vars/cons=10125/64 | time=0.37s
# SP4 | status=OptimizationStatus.OPTIMAL | obj=259682.78028885176 | vars/cons=74000/512 | time=4.29s

# %%
df_long.shape
# Out:
# (3200, 9)

# %%
df_long = df_long[df_long["label"].notna()].copy()
df_long = df_long.merge(nominal, on=["Archivo","n","Capacidad"])
df_long["inc_vs_sp"] = (df_long["objective"] - df_long["Nominal"])/df_long["Nominal"]
df_long
# Out:
#       Archivo    n  Capacidad  %Desv  t                split      objective  \
# 0     s000.kp   50    14778.0    0.0  0              nominal   21047.483259
# 1     s000.kp   50    14778.0    0.1  1  1.00-0.00-0.00-0.00   21047.483259
# 2     s000.kp   50    14778.0    0.1  2  0.50-0.50-0.00-0.00   21044.947595
# 3     s000.kp   50    14778.0    0.1  2  0.25-0.75-0.00-0.00   21025.350302
# 4     s000.kp   50    14778.0    0.1  2  0.50-0.50-0.00-0.00   21044.947595
# ...       ...  ...        ...    ... ..                  ...            ...
# 3195  s019.kp  500   116396.0    2.0  2  0.25-0.75-0.00-0.00  248696.402225
# 3196  s019.kp  500   116396.0    2.0  2  0.50-0.50-0.00-0.00  235736.999146
# 3197  s019.kp  500   116396.0    2.0  2  0.75-0.25-0.00-0.00  223802.613366
# 3198  s019.kp  500   116396.0    2.0  3  0.25-0.50-0.25-0.00  250671.128779
# 3199  s019.kp  500   116396.0    2.0  4  0.00-0.50-0.25-0.25  259682.780289
#
#          time_s        label        Nominal  inc_vs_sp
# 0           NaN      Nominal   21047.483259   0.000000
# 1      0.007373          SP1   21047.483259   0.000000
# 2      0.033474          SP2   21047.483259  -0.000120
# 3      0.034831  SP2split_75   21047.483259  -0.001052
# 4      0.027512  SP2split_50   21047.483259  -0.000120
# ...         ...          ...            ...        ...
# 3195   0.202790  SP2split_75  204088.143351   0.218573
# 3196   0.180725  SP2split_50  204088.143351   0.155074
# 3197   0.127536  SP2split_25  204088.143351   0.096598
# 3198   1.494576          SP3  204088.143351   0.228249
# 3199  51.999212          SP4  204088.143351   0.272405
#
# [3200 rows x 11 columns]

# %%
df_long.value_counts("label")
# Out:
# label
# Nominal        400
# SP1            400
# SP2            400
# SP2split_25    400
# SP2split_50    400
# SP2split_75    400
# SP3            400
# SP4            400
# Name: count, dtype: int64

# %% [markdown]
# ## Estudio valor objetivo y tiempo

# %%
import numpy as np
from scipy.stats import t as student_t

# ---------- utilidades ----------
def iqr(x):
    x = np.asarray(x, dtype=float)
    if x.size < 2: return np.nan
    return np.percentile(x, 75) - np.percentile(x, 25)

def ci95(x):
    """Devuelve (low, high) del IC95% para la media."""
    x = np.asarray(x, dtype=float)
    m = x.size
    if m < 2: return (np.nan, np.nan)
    mean = np.mean(x)
    se   = np.std(x, ddof=1) / np.sqrt(m)
    tcrit = student_t.ppf(0.975, df=m-1)
    h = tcrit * se
    return (mean - h, mean + h)



# ---------- agregado: TODO junto (incremento + objetivo + tiempo) ----------
agg_all = (
    df_long
    .groupby(["n", "%Desv", "label"])
    .agg(
        count       = ("inc_vs_sp", "size"),

        # incremento vs SP
        inc_mean    = ("inc_vs_sp", "mean"),
        inc_median  = ("inc_vs_sp", "median"),
        inc_std     = ("inc_vs_sp", "std"),
        inc_iqr     = ("inc_vs_sp", iqr),
        inc_ci_low  = ("inc_vs_sp", lambda x: ci95(x)[0]),
        inc_ci_high = ("inc_vs_sp", lambda x: ci95(x)[1]),

        # objetivo absoluto
        obj_mean    = ("objective", "mean"),
        obj_median  = ("objective", "median"),
        obj_std     = ("objective", "std"),
        obj_iqr     = ("objective", iqr),
        obj_ci_low  = ("objective", lambda x: ci95(x)[0]),
        obj_ci_high = ("objective", lambda x: ci95(x)[1]),

        # tiempo
        time_mean    = ("time_s", "mean"),
        time_median  = ("time_s", "median"),
        time_std     = ("time_s", "std"),
        time_iqr     = ("time_s", iqr),
        time_ci_low  = ("time_s", lambda x: ci95(x)[0]),
        time_ci_high = ("time_s", lambda x: ci95(x)[1]),
    )
    .reset_index()
)

agg_all = agg_all[agg_all["label"].isin(["SP1", "SP2", "SP3", "SP4", "SP2split_25", "SP2split_50", "SP2split_75"])]
# Clasificación fija de los niveles de incertidumbre
def clasificar_incertidumbre(x):
    if x == 0.1:
        return "Muy baja"
    elif x == 0.5:
        return "Baja"
    elif x == 1.0:
        return "Media"
    elif x == 1.5:
        return "Alta"
    elif x == 2.0:
        return "Muy alta"
    else:
        return "No clasificado"

# Añadir la columna 'Nivel' al DataFrame agg_all
agg_all["Incertidumbre"] = agg_all["%Desv"].apply(clasificar_incertidumbre)

# redondeo suave
for c in [col for col in agg_all.columns if any(s in col for s in ("_mean","_median","_std","_iqr","_ci_low","_ci_high"))]:
    agg_all[c] = agg_all[c].astype(float).round(6)

# ---------- derivados: solo INC, solo OBJETIVO y solo TIEMPO ----------
cols_keys = ["n","Incertidumbre","label"]

agg_inc  = agg_all[cols_keys + ["inc_mean","inc_ci_low","inc_ci_high", "inc_std", "inc_median","inc_iqr"]].copy()
agg_obj = agg_all[cols_keys + ["obj_mean","obj_ci_low","obj_ci_high", "obj_std", "obj_median","obj_iqr"]].copy()
agg_time = agg_all[cols_keys + ["time_mean","time_ci_low","time_ci_high", "time_std", "time_median","time_iqr"]].copy()

agg_inc_A = agg_inc[agg_inc["label"].isin(["SP1", "SP2", "SP3", "SP4"])].copy()
agg_obj_A = agg_obj[agg_obj["label"].isin(["SP1", "SP2", "SP3", "SP4"])].copy()
agg_time_A = agg_time[agg_time["label"].isin(["SP1", "SP2", "SP3", "SP4"])].copy()

agg_inc_B = agg_inc[agg_inc["label"].isin(["SP2split_25", "SP2split_50", "SP2split_75"])].copy()
agg_obj_B = agg_obj[agg_obj["label"].isin(["SP2split_25", "SP2split_50", "SP2split_75"])].copy()
agg_time_B = agg_time[agg_time["label"].isin(["SP2split_25", "SP2split_50", "SP2split_75"])].copy()



# ---------- vistazo rápido ----------
try:
    display(agg_all.head(10))
    display(agg_inc.head(10)); display(agg_obj.head(10)); display(agg_time.head(10))
except Exception:
    pass
# Out:
#      n  %Desv        label  count  inc_mean  inc_median   inc_std   inc_iqr  \
# 1   50    0.1          SP1     20  0.000000    0.000000  0.000000  0.000000
# 2   50    0.1          SP2     20 -0.002022   -0.002166  0.002172  0.002980
# 3   50    0.1  SP2split_25     20 -0.000705   -0.000861  0.000707  0.000908
# 4   50    0.1  SP2split_50     20 -0.002022   -0.002166  0.002172  0.002980
# 5   50    0.1  SP2split_75     20 -0.002069   -0.001742  0.001570  0.002347
# 6   50    0.1          SP3     20 -0.002148   -0.002123  0.002940  0.003768
# 7   50    0.1          SP4     20 -0.001271   -0.000984  0.002919  0.002959
# 8   50    0.5          SP1     20  0.000000    0.000000  0.000000  0.000000
# 9   50    0.5          SP2     20 -0.000537   -0.001813  0.012117  0.014265
# 10  50    0.5  SP2split_25     20  0.000389   -0.000491  0.005313  0.007814
#
#     inc_ci_low  inc_ci_high  ...      obj_iqr    obj_ci_low   obj_ci_high  \
# 1     0.000000     0.000000  ...  1616.378657  19275.794544  20635.381964
# 2    -0.003039    -0.001005  ...  1558.395275  19234.987797  20595.892976
# 3    -0.001036    -0.000374  ...  1595.956845  19263.391342  20619.207385
# 4    -0.003039    -0.001005  ...  1558.395275  19234.987797  20595.892976
# 5    -0.002804    -0.001334  ...  1629.728818  19237.820039  20590.355168
# 6    -0.003524    -0.000772  ...  1478.361155  19236.899449  20587.454813
# 7    -0.002638     0.000095  ...  1644.925371  19250.285584  20609.968331
# 8     0.000000     0.000000  ...  1616.378657  19275.794544  20635.381964
# 9    -0.006208     0.005134  ...  1391.056898  19249.422417  20642.057062
# 10   -0.002097     0.002876  ...  1641.909029  19296.278150  20624.831352
#
#     time_mean  time_median  time_std  time_iqr  time_ci_low  time_ci_high  \
# 1    0.008380     0.005912  0.006056  0.003137     0.005546      0.011215
# 2    0.029132     0.019328  0.022417  0.010688     0.018641      0.039623
# 3    0.017650     0.014944  0.005491  0.009433     0.015080      0.020220
# 4    0.025855     0.018917  0.015873  0.011562     0.018426      0.033284
# 5    0.029672     0.021914  0.014583  0.013466     0.022847      0.036498
# 6    0.147253     0.108495  0.075141  0.095420     0.112086      0.182420
# 7    1.634489     1.056878  0.971369  0.959152     1.179874      2.089104
# 8    0.005168     0.004994  0.001084  0.001425     0.004660      0.005675
# 9    0.017701     0.017202  0.003266  0.003996     0.016173      0.019229
# 10   0.014131     0.013206  0.002881  0.001882     0.012783      0.015480
#
#     Incertidumbre
# 1        Muy baja
# 2        Muy baja
# 3        Muy baja
# 4        Muy baja
# 5        Muy baja
# 6        Muy baja
# 7        Muy baja
# 8            Baja
# 9            Baja
# 10           Baja
#
# [10 rows x 23 columns]
#      n Incertidumbre        label  inc_mean  inc_ci_low  inc_ci_high  \
# 1   50      Muy baja          SP1  0.000000    0.000000     0.000000
# 2   50      Muy baja          SP2 -0.002022   -0.003039    -0.001005
# 3   50      Muy baja  SP2split_25 -0.000705   -0.001036    -0.000374
# 4   50      Muy baja  SP2split_50 -0.002022   -0.003039    -0.001005
# 5   50      Muy baja  SP2split_75 -0.002069   -0.002804    -0.001334
# 6   50      Muy baja          SP3 -0.002148   -0.003524    -0.000772
# 7   50      Muy baja          SP4 -0.001271   -0.002638     0.000095
# 8   50          Baja          SP1  0.000000    0.000000     0.000000
# 9   50          Baja          SP2 -0.000537   -0.006208     0.005134
# 10  50          Baja  SP2split_25  0.000389   -0.002097     0.002876
#
#      inc_std  inc_median   inc_iqr
# 1   0.000000    0.000000  0.000000
# 2   0.002172   -0.002166  0.002980
# 3   0.000707   -0.000861  0.000908
# 4   0.002172   -0.002166  0.002980
# 5   0.001570   -0.001742  0.002347
# 6   0.002940   -0.002123  0.003768
# 7   0.002919   -0.000984  0.002959
# 8   0.000000    0.000000  0.000000
# 9   0.012117   -0.001813  0.014265
# 10  0.005313   -0.000491  0.007814
#      n Incertidumbre        label      obj_mean    obj_ci_low   obj_ci_high  \
# 1   50      Muy baja          SP1  19955.588254  19275.794544  20635.381964
# 2   50      Muy baja          SP2  19915.440386  19234.987797  20595.892976
# 3   50      Muy baja  SP2split_25  19941.299363  19263.391342  20619.207385
# 4   50      Muy baja  SP2split_50  19915.440386  19234.987797  20595.892976
# 5   50      Muy baja  SP2split_75  19914.087603  19237.820039  20590.355168
# 6   50      Muy baja          SP3  19912.177131  19236.899449  20587.454813
# 7   50      Muy baja          SP4  19930.126958  19250.285584  20609.968331
# 8   50          Baja          SP1  19955.588254  19275.794544  20635.381964
# 9   50          Baja          SP2  19945.739740  19249.422417  20642.057062
# 10  50          Baja  SP2split_25  19960.554751  19296.278150  20624.831352
#
#         obj_std    obj_median      obj_iqr
# 1   1452.505950  19841.211648  1616.378657
# 2   1453.913768  19850.690378  1558.395275
# 3   1448.476825  19818.613733  1595.956845
# 4   1453.913768  19850.690378  1558.395275
# 5   1444.971682  19836.687028  1629.728818
# 6   1442.856615  19821.062826  1478.361155
# 7   1452.607792  19827.192316  1644.925371
# 8   1452.505950  19841.211648  1616.378657
# 9   1487.811727  20010.029332  1391.056898
# 10  1419.350755  19810.040465  1641.909029
#      n Incertidumbre        label  time_mean  time_ci_low  time_ci_high  \
# 1   50      Muy baja          SP1   0.008380     0.005546      0.011215
# 2   50      Muy baja          SP2   0.029132     0.018641      0.039623
# 3   50      Muy baja  SP2split_25   0.017650     0.015080      0.020220
# 4   50      Muy baja  SP2split_50   0.025855     0.018426      0.033284
# 5   50      Muy baja  SP2split_75   0.029672     0.022847      0.036498
# 6   50      Muy baja          SP3   0.147253     0.112086      0.182420
# 7   50      Muy baja          SP4   1.634489     1.179874      2.089104
# 8   50          Baja          SP1   0.005168     0.004660      0.005675
# 9   50          Baja          SP2   0.017701     0.016173      0.019229
# 10  50          Baja  SP2split_25   0.014131     0.012783      0.015480
#
#     time_std  time_median  time_iqr
# 1   0.006056     0.005912  0.003137
# 2   0.022417     0.019328  0.010688
# 3   0.005491     0.014944  0.009433
# 4   0.015873     0.018917  0.011562
# 5   0.014583     0.021914  0.013466
# 6   0.075141     0.108495  0.095420
# 7   0.971369     1.056878  0.959152
# 8   0.001084     0.004994  0.001425
# 9   0.003266     0.017202  0.003996
# 10  0.002881     0.013206  0.001882

# %%
sp_experimento_A = agg_all[agg_all["label"].isin(["SP2", "SP3", "SP4"])].copy()
orden = ["Muy baja", "Baja", "Media", "Alta", "Muy alta"]
sp_experimento_A["Incertidumbre"] = pd.Categorical(sp_experimento_A["Incertidumbre"], categories=orden, ordered=True)



# --- 4) Dataset para la FIGURA X (fijar n=200; columnas: Nivel, Método, mean/low/high) ---
sp_experimento_A_fig_n_200_incertidumbre = (
    sp_experimento_A[sp_experimento_A["n"] == 200]
    .loc[:, ["Incertidumbre", "label", "inc_mean", "inc_ci_low", "inc_ci_high"]]
    .sort_values(["Incertidumbre", "label"])
)



# --- 5B) (Opcional) Guardar a CSV si lo prefieres ---
sp_experimento_A_fig_n_200_incertidumbre_excel = sp_experimento_A_fig_n_200_incertidumbre.copy()

# Multiplicar por 100 y redondear a 2 decimales en las tres columnas
cols_pct = ["inc_mean", "inc_ci_low", "inc_ci_high"]
sp_experimento_A_fig_n_200_incertidumbre_excel.loc[:, cols_pct] = (
    sp_experimento_A_fig_n_200_incertidumbre_excel.loc[:, cols_pct]
    .applymap(lambda x: round(100*x, 2))
)


sp_experimento_B = agg_all[agg_all["label"].isin(["SP2split_25", "SP2split_50", "SP2split_75"])].copy()
sp_experimento_B["Incertidumbre"] = sp_experimento_B["%Desv"].apply(clasificar_incertidumbre)
sp_experimento_B["Incertidumbre"] = pd.Categorical(sp_experimento_B["Incertidumbre"], categories=orden, ordered=True)
sp_experimento_B_fig_n_200_incertidumbre = (
    sp_experimento_B[sp_experimento_B["n"] == 200]
    .loc[:, ["Incertidumbre", "label", "inc_mean", "inc_ci_low", "inc_ci_high"]]
    .sort_values(["Incertidumbre", "label"])
)

sp_experimento_B_fig_n_200_incertidumbre_excel = sp_experimento_B_fig_n_200_incertidumbre.copy()
sp_experimento_B_fig_n_200_incertidumbre_excel.loc[:, cols_pct] = (
    sp_experimento_B_fig_n_200_incertidumbre_excel.loc[:, cols_pct]
    .applymap(lambda x: round(100*x, 2))
)

display(sp_experimento_A_fig_n_200_incertidumbre_excel)
display(sp_experimento_B_fig_n_200_incertidumbre_excel)
# Out:
# /tmp/ipython-input-2989964776.py:23: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   .applymap(lambda x: round(100*x, 2))
# /tmp/ipython-input-2989964776.py:39: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   .applymap(lambda x: round(100*x, 2))
#     Incertidumbre label  inc_mean  inc_ci_low  inc_ci_high
# 74       Muy baja   SP2      0.02       -0.02         0.05
# 78       Muy baja   SP3      0.10        0.06         0.14
# 79       Muy baja   SP4     -0.03       -0.11         0.04
# 81           Baja   SP2      0.83        0.58         1.08
# 85           Baja   SP3      1.63        1.43         1.83
# 86           Baja   SP4      1.39        1.03         1.75
# 88          Media   SP2      3.91        3.42         4.40
# 92          Media   SP3      6.44        5.96         6.93
# 93          Media   SP4      6.93        6.24         7.61
# 95           Alta   SP2      9.24        8.56         9.92
# 99           Alta   SP3     14.37       13.67        15.07
# 100          Alta   SP4     16.69       15.74        17.63
# 102      Muy alta   SP2     15.53       14.68        16.39
# 106      Muy alta   SP3     23.83       22.96        24.71
# 107      Muy alta   SP4     28.61       27.47        29.76
#     Incertidumbre        label  inc_mean  inc_ci_low  inc_ci_high
# 75       Muy baja  SP2split_25     -0.07       -0.10        -0.03
# 76       Muy baja  SP2split_50      0.02       -0.02         0.05
# 77       Muy baja  SP2split_75      0.09        0.04         0.14
# 82           Baja  SP2split_25      0.08       -0.10         0.27
# 83           Baja  SP2split_50      0.83        0.58         1.08
# 84           Baja  SP2split_75      1.62        1.40         1.83
# 89          Media  SP2split_25      1.47        1.15         1.79
# 90          Media  SP2split_50      3.91        3.42         4.40
# 91          Media  SP2split_75      6.49        6.06         6.91
# 96           Alta  SP2split_25      4.10        3.68         4.53
# 97           Alta  SP2split_50      9.24        8.56         9.92
# 98           Alta  SP2split_75     14.51       13.90        15.13
# 103      Muy alta  SP2split_25      7.29        6.76         7.83
# 104      Muy alta  SP2split_50     15.53       14.68        16.39
# 105      Muy alta  SP2split_75     24.04       23.25        24.82

# %%
## Figura 2 - > Para cada n, y un nivel fijo de incertidumbre (Alta), vemos como varia cada enfoque
sp_experimento_A_fig_incertidumbre_fija_alta = sp_experimento_A[sp_experimento_A["Incertidumbre"] == "Alta"].copy()
sp_experimento_A_fig_incertidumbre_fija_alta = sp_experimento_A_fig_incertidumbre_fija_alta.loc[:, ["n", "label", "inc_mean", "inc_ci_low", "inc_ci_high"]]
sp_experimento_A_fig_incertidumbre_fija_alta_excel = sp_experimento_A_fig_incertidumbre_fija_alta.copy()
sp_experimento_A_fig_incertidumbre_fija_alta_excel.loc[:, cols_pct] = (
    sp_experimento_A_fig_incertidumbre_fija_alta_excel.loc[:, cols_pct]
    .applymap(lambda x: round(100*x, 2))
)
sp_experimento_A_fig_incertidumbre_fija_alta_excel

sp_experimento_B_fig_incertidumbre_fija_alta = sp_experimento_B[sp_experimento_B["Incertidumbre"] == "Alta"].copy()
sp_experimento_B_fig_incertidumbre_fija_alta = sp_experimento_B_fig_incertidumbre_fija_alta.loc[:, ["n", "label", "inc_mean", "inc_ci_low", "inc_ci_high"]]
sp_experimento_B_fig_incertidumbre_fija_alta_excel = sp_experimento_B_fig_incertidumbre_fija_alta.copy()
sp_experimento_B_fig_incertidumbre_fija_alta_excel.loc[:, cols_pct] = (
    sp_experimento_B_fig_incertidumbre_fija_alta_excel.loc[:, cols_pct]
    .applymap(lambda x: round(100*x, 2))
)
sp_experimento_B_fig_incertidumbre_fija_alta_excel
# Out:
# /tmp/ipython-input-1708103052.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   .applymap(lambda x: round(100*x, 2))
# /tmp/ipython-input-1708103052.py:16: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   .applymap(lambda x: round(100*x, 2))
#        n        label  inc_mean  inc_ci_low  inc_ci_high
# 24    50  SP2split_25      3.28        2.56         3.99
# 25    50  SP2split_50      7.32        5.81         8.84
# 26    50  SP2split_75     11.52        9.98        13.06
# 60   100  SP2split_25      3.36        2.76         3.97
# 61   100  SP2split_50      8.05        7.12         8.97
# 62   100  SP2split_75     16.03       15.28        16.79
# 96   200  SP2split_25      4.10        3.68         4.53
# 97   200  SP2split_50      9.24        8.56         9.92
# 98   200  SP2split_75     14.51       13.90        15.13
# 132  500  SP2split_25      5.38        5.08         5.68
# 133  500  SP2split_50      9.41        8.99         9.83
# 134  500  SP2split_75     13.38       12.82        13.93

# %%
## Figura 3 - Tiempo computacional para Nivel de Incertidumbre Alta
sp_experimento_A_tiempo_incertidumbre_alta = sp_experimento_A.copy()
sp_experimento_A_tiempo_incertidumbre_alta = sp_experimento_A_tiempo_incertidumbre_alta[sp_experimento_A_tiempo_incertidumbre_alta["Incertidumbre"] == "Alta"]
sp_experimento_A_tiempo_incertidumbre_alta = sp_experimento_A_tiempo_incertidumbre_alta.loc[:, ["n", "label", "time_mean", "time_ci_low", "time_ci_high"]]
sp_experimento_A_tiempo_incertidumbre_alta


sp_experimento_B_tiempo_incertidumbre_alta  = sp_experimento_B.copy()
sp_experimento_B_tiempo_incertidumbre_alta = sp_experimento_B_tiempo_incertidumbre_alta[sp_experimento_B_tiempo_incertidumbre_alta["Incertidumbre"] == "Alta"]
sp_experimento_B_tiempo_incertidumbre_alta = sp_experimento_B_tiempo_incertidumbre_alta.loc[:, ["n", "label", "time_mean", "time_ci_low", "time_ci_high"]]
sp_experimento_B_tiempo_incertidumbre_alta
# Out:
#        n        label  time_mean  time_ci_low  time_ci_high
# 24    50  SP2split_25   0.014835     0.012256      0.017413
# 25    50  SP2split_50   0.017850     0.015938      0.019762
# 26    50  SP2split_75   0.020740     0.018707      0.022773
# 60   100  SP2split_25   0.026763     0.024049      0.029477
# 61   100  SP2split_50   0.032755     0.029632      0.035877
# 62   100  SP2split_75   0.039715     0.035316      0.044115
# 96   200  SP2split_25   0.054204     0.045917      0.062490
# 97   200  SP2split_50   0.071724     0.064126      0.079322
# 98   200  SP2split_75   0.080846     0.071100      0.090591
# 132  500  SP2split_25   0.143927     0.128038      0.159815
# 133  500  SP2split_50   0.183387     0.164051      0.202724
# 134  500  SP2split_75   0.250648     0.223730      0.277567

# %%
agg_all_sin_nominal = agg_all[agg_all["label"].isin(["SP1", "SP2", "SP3", "SP4", "SP2split_25", "SP2split_50", "SP2split_75"])]
agg_all_sin_nominal

tabla_mean_inc = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["inc_mean"].mean().reset_index()
tabla_mean_obj = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["obj_mean"].mean().reset_index()
tabla_mean_time = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["time_mean"].mean().reset_index()

tabla_cilow_inc = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["inc_ci_low"].mean().reset_index()
tabla_cilow_obj = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["obj_ci_low"].mean().reset_index()
tabla_cilow_time = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["time_ci_low"].mean().reset_index()

tabla_cihigh_inc = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["inc_ci_high"].mean().reset_index()
tabla_cihigh_obj = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["obj_ci_high"].mean().reset_index()
tabla_cihigh_time = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["time_ci_high"].mean().reset_index()

tabla_std_inc = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["inc_std"].mean().reset_index()
tabla_std_obj = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["obj_std"].mean().reset_index()
tabla_std_time = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["time_std"].mean().reset_index()

tabla_median_inc = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["inc_median"].mean().reset_index()
tabla_median_obj = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["obj_median"].mean().reset_index()
tabla_median_time = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["time_median"].mean().reset_index()

tabla_iqr_inc = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["inc_iqr"].mean().reset_index()
tabla_iqr_obj = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["obj_iqr"].mean().reset_index()
tabla_iqr_time = agg_all_sin_nominal.groupby(["n", "Incertidumbre", "label"])["time_iqr"].mean().reset_index()

# %%
# ---------- exportación ----------
with pd.ExcelWriter("Experimentos Computacionales SP.xlsx") as writer:

  # TABLAS PRINCIPALES

    agg_inc_A.to_excel(writer, sheet_name="agg_inc_A", index=False)
    agg_obj_A.to_excel(writer, sheet_name="agg_obj_A", index=False)
    agg_time_A.to_excel(writer, sheet_name="agg_time_A", index=False)
    agg_inc_B.to_excel(writer, sheet_name="agg_inc_B", index=False)
    agg_obj_B.to_excel(writer, sheet_name="agg_obj_B", index=False)
    agg_time_B.to_excel(writer, sheet_name="agg_time_B", index=False)

  # DATOS DE LAS FIGURAS

    sp_experimento_A_fig_n_200_incertidumbre_excel.to_excel(writer, sheet_name="Exp_A_fig_n_fijo_200", index=False)
    sp_experimento_B_fig_n_200_incertidumbre_excel.to_excel(writer, sheet_name="Exp_B_fig_n_fijo_200", index=False)

    sp_experimento_A_fig_incertidumbre_fija_alta_excel.to_excel(writer, sheet_name="Exp_A_fig_incer_alta", index=False)
    sp_experimento_B_fig_incertidumbre_fija_alta_excel.to_excel(writer, sheet_name="Exp_B_fig_incer_alta", index=False)

    sp_experimento_A_tiempo_incertidumbre_alta.to_excel(writer, sheet_name="Exp_A_tiempo_incer_alta", index=False)
    sp_experimento_B_tiempo_incertidumbre_alta.to_excel(writer, sheet_name="Exp_B_tiempo_incer_alta", index=False)

  # DATOS TABLAS

    agg_all.to_excel(writer, sheet_name="all", index=False)
    agg_inc.to_excel(writer, sheet_name="inc", index=False)
    agg_obj.to_excel(writer, sheet_name="obj", index=False)
    agg_time.to_excel(writer, sheet_name="time", index=False)

  # REPORTE DE MÉTRICAS

    tabla_mean_inc.to_excel(writer, sheet_name="tabla_mean_inc", index=False)
    tabla_mean_obj.to_excel(writer, sheet_name="tabla_mean_obj", index=False)
    tabla_mean_time.to_excel(writer, sheet_name="tabla_mean_time", index=False)
    tabla_cilow_inc.to_excel(writer, sheet_name="tabla_cilow_inc", index=False)
    tabla_cilow_obj.to_excel(writer, sheet_name="tabla_cilow_obj", index=False)
    tabla_cilow_time.to_excel(writer, sheet_name="tabla_cilow_time", index=False)
    tabla_cihigh_inc.to_excel(writer, sheet_name="tabla_cihigh_inc", index=False)
    tabla_cihigh_obj.to_excel(writer, sheet_name="tabla_cihigh_obj", index=False)
    tabla_cihigh_time.to_excel(writer, sheet_name="tabla_cihigh_time", index=False)
    tabla_std_inc.to_excel(writer, sheet_name="tabla_std_inc", index=False)
    tabla_std_obj.to_excel(writer, sheet_name="tabla_std_obj", index=False)
    tabla_std_time.to_excel(writer, sheet_name="tabla_std_time", index=False)
    tabla_median_inc.to_excel(writer, sheet_name="tabla_median_inc", index=False)
    tabla_median_obj.to_excel(writer, sheet_name="tabla_median_obj", index=False)
    tabla_median_time.to_excel(writer, sheet_name="tabla_median_time", index=False)
    tabla_iqr_inc.to_excel(writer, sheet_name="tabla_iqr_inc", index=False)
    tabla_iqr_obj.to_excel(writer, sheet_name="tabla_iqr_obj", index=False)
    tabla_iqr_time.to_excel(writer, sheet_name="tabla_iqr_time", index=False)




# Si prefieres no forzar descarga, comenta la siguiente línea
files.download("Experimentos Computacionales SP.xlsx")

# %% [markdown]
# ## bertsimas model

# %%
# ================== Bertsimas–Sim (fraccional) con MIP + Excel (XlsxWriter) ==================
import sys, subprocess, time
import numpy as np
import pandas as pd
from mip import Model, CONTINUOUS, MAXIMIZE, CBC, OptimizationStatus

def solve_nominal_fractional_mip(c_bar, pesos, capacidad, time_limit=3600, solver_name=CBC):
    """Max sum c_bar x  s.a. sum w x <= cap, 0<=x<=1 (fraccional) con MIP."""
    c_bar = np.asarray(c_bar, float)
    pesos = np.asarray(pesos, float)
    n = c_bar.size

    m = Model(sense=MAXIMIZE, solver_name=solver_name)
    m.max_seconds = time_limit
    x = [m.add_var(var_type=CONTINUOUS, lb=0.0, ub=1.0, name=f"x_{j}") for j in range(n)]

    m.objective = sum(c_bar[j]*x[j] for j in range(n))
    m += (sum(pesos[j]*x[j] for j in range(n)) <= capacidad), "cap"

    t0 = time.perf_counter(); status = m.optimize(); t1 = time.perf_counter()
    obj = m.objective_value if status in (OptimizationStatus.OPTIMAL, OptimizationStatus.FEASIBLE) else np.nan
    return float(obj), status, t1-t0


def solve_knapsack_bs_mip(c_bar, c_hat, pesos, capacidad, gamma, time_limit=3600, solver_name=CBC):
    """
    Bertsimas–Sim robusto (fraccional, x in [0,1]) con MIP (CBC):
      max  sum c_bar_j x_j  - gamma*z  - sum p_j
      s.a. d_j x_j - z - p_j <= 0  (∀j)
           sum w_j x_j <= capacidad
           x ∈ [0,1], z>=0, p>=0
    Devuelve además eval_cx = sum c_bar_j x_j (evaluación nominal de la solución x*).
    """
    c_bar = np.asarray(c_bar, float)
    c_hat = np.asarray(c_hat, float)
    pesos = np.asarray(pesos, float)
    n = c_bar.size
    assert c_hat.size == n and pesos.size == n, "Dimensiones incoherentes"

    m = Model(sense=MAXIMIZE, solver_name=solver_name)
    m.max_seconds = time_limit

    # Variables
    x = [m.add_var(var_type=CONTINUOUS, lb=0.0, ub=1.0, name=f"x_{j}") for j in range(n)]
    z = m.add_var(var_type=CONTINUOUS, lb=0.0, name="z")
    p = [m.add_var(var_type=CONTINUOUS, lb=0.0, name=f"p_{j}") for j in range(n)]

    # Objetivo robusto
    m.objective = sum(c_bar[j]*x[j] for j in range(n)) - gamma*z - sum(p[j] for j in range(n))

    # Capacidad
    m += (sum(pesos[j]*x[j] for j in range(n)) <= capacidad), "cap"

    # Robustez: d_j x_j - z - p_j <= 0
    for j in range(n):
        m += (c_hat[j]*x[j] - z - p[j] <= 0), f"rob_{j}"

    t0 = time.perf_counter()
    status = m.optimize()
    t1 = time.perf_counter()
    ok = status in (OptimizationStatus.OPTIMAL, OptimizationStatus.FEASIBLE)
    obj = float(m.objective_value) if ok else np.nan

    # Extra: evaluación nominal de la solución x* (sin penalizaciones)
    if ok:
        sol_x = np.array([var.x for var in x], dtype=float)
        eval_cx = float(np.dot(c_bar, sol_x))
        sol_z = float(z.x)
        sol_p = np.array([var.x for var in p], dtype=float)
    else:
        sol_x = None
        eval_cx = np.nan
        sol_z = np.nan
        sol_p = None

    return {
        "ok": ok,
        "status": str(status),
        "objective": obj,         # robusto: c·x - gamma z - sum p
        "eval_cx": eval_cx,       # nominal: c·x
        "x": sol_x,
        "z": sol_z,
        "p": sol_p,
        "time_s": round(t1 - t0, 6),
        "n_vars": m.num_cols,
        "n_constrs": m.num_rows,
        "model": m,
    }


def total_solver_bs_mip(
    df_kplib,
    pct_desviacion_list=(0.10, 0.30, 0.50),
    gamma_pcts=(0.00, 0.05, 0.10, 0.25, 0.50, 0.75, 1.00),
    sizes=(50, 100, 200, 500),
    k=20,
    time_limit=3600,
    check_nominal=True,
):
    filas = []

    for pct_desviacion in pct_desviacion_list:
        for n_target in sizes:
            df_sub = df_kplib[df_kplib["n"] == n_target].head(k)
            print(f"\n=== n = {n_target} | {len(df_sub)} instancias | pct_desv={pct_desviacion} ===")
            for idx, row in df_sub.iterrows():
                cbar = np.array(row["Utilidades"], float)
                w    = np.array(row["Pesos"], float)
                cap  = float(row["Capacidad"])
                arc  = row["Archivo"] if "Archivo" in df_kplib.columns else f"idx_{idx}"
                n    = cbar.size
                assert w.size == n, f"Dim mismatch en {arc}"

                # d_j = pct * |c̄_j|
                chat = np.abs(pct_desviacion * cbar)

                # Chequeo nominal (Γ=0) vs LP nominal fraccional (con MIP también)
                if check_nominal:
                    f_nom, st_nom, _ = solve_nominal_fractional_mip(cbar, w, cap, time_limit=time_limit)
                else:
                    f_nom = np.nan

                for pct in gamma_pcts:
                    gamma = int(round(pct * n))
                    sol = solve_knapsack_bs_mip(cbar, chat, w, cap, gamma, time_limit=time_limit)

                    if sol["ok"]:
                        if check_nominal and gamma == 0 and np.isfinite(f_nom):
                            diff = abs(sol["objective"] - f_nom)
                            if diff > 1e-6:
                                print(f"[Aviso] {arc} | Γ=0: nominal={f_nom:.6f}, robust={sol['objective']:.6f} (ambos fraccionales)")

                        filas.append({
                            "Archivo": arc,
                            "n": int(row["n"]),
                            "Capacidad": cap,
                            "%Desv": pct_desviacion,
                            "Gamma": gamma,
                            "%Gamma": pct,
                            "Valor objetivo": sol["objective"],   # robusto
                            "Eval c·x": sol["eval_cx"],            # nominal de la solución
                            "z": sol["z"],
                            "Tiempo (s)": sol["time_s"],
                            "Status": sol["status"],
                            "n_vars": sol["n_vars"],
                            "n_constrs": sol["n_constrs"],
                        })
                    else:
                        print(f"  {arc} | Γ={gamma}: fallo -> {sol['status']}")

    # ---- DataFrame largo ----
    df_long = pd.DataFrame(filas)
    if not df_long.empty:
        df_long[["Valor objetivo", "Eval c·x", "z", "Tiempo (s)"]] = df_long[["Valor objetivo", "Eval c·x", "z", "Tiempo (s)"]].round(6)

    print("\n=== Resumen (primeras filas) ===")
    print(df_long.head(10))
    # ---- Tabla wide: objetivos, evaluación c·x y tiempos por Γ ----
    keys = ["Archivo", "n", "Capacidad", "%Desv"]

    def rename_cols(df, prefix):
        ren = {}
        for col in df.columns:
            if isinstance(col, float):  # columnas de %Gamma
                ren[col] = f"{prefix}_Gamma{int(round(col*100))}%"
        return df.rename(columns=ren)

    # f(Γ)
    wide_obj = (
        df_long.pivot(index=keys, columns="%Gamma", values="Valor objetivo")
              .sort_index(axis=1)
              .reset_index()
    )
    wide_obj = rename_cols(wide_obj, "f")

    # c·x(Γ)
    wide_cx = (
        df_long.pivot(index=keys, columns="%Gamma", values="Eval c·x")
              .sort_index(axis=1)
              .reset_index()
    )
    wide_cx = rename_cols(wide_cx, "cx")

    # t(Γ)
    wide_time = (
        df_long.pivot(index=keys, columns="%Gamma", values="Tiempo (s)")
              .sort_index(axis=1)
              .reset_index()
    )
    wide_time = rename_cols(wide_time, "tiempo")

    # Unimos
    df_wide = wide_obj.merge(wide_cx, on=keys, how="inner").merge(wide_time, on=keys, how="inner")

    # print("\n=== Wide (primeras filas) ===")
    # print(df_wide.head(10))

    # # ---- Guardar Excel con XlsxWriter ----
    # out_name = "BertsimasSim_MIP.xlsx"
    # with pd.ExcelWriter(out_name, engine=EXCEL_ENGINE) as writer:
    #     df_long.to_excel(writer, sheet_name="long", index=False)
    #     df_wide.to_excel(writer, sheet_name="wide", index=False)

    # if IN_COLAB:
    #     files.download(out_name)
    # else:
    #     print(f"[Info] Archivo guardado: {out_name}")

    return df_long, df_wide, wide_time, wide_obj, wide_cx


# ================== EJECUCIÓN (ejemplo) ==================
long_bs, wide_bs, wide_time_bs, wide_obj_bs, wide_cx_bs = total_solver_bs_mip(
    df_kplib,
    pct_desviacion_list=(0.10, 0.30, 0.50),
    gamma_pcts=(0.00, 0.05, 0.10, 0.25, 0.50, 0.75, 1.00),
    sizes=(50, 100, 200, 500),
    k=20,
    time_limit=3600,
    check_nominal=True,
)

# %%
wide_obj_bs.to_excel("wide_obj_bs.xlsx")
wide_time_bs.to_excel("wide_time_bs.xlsx")
wide_bs.to_excel("wide_bs.xlsx")
files.download("wide_obj_bs.xlsx")
files.download("wide_time_bs.xlsx")
files.download("wide_bs.xlsx")

# %% [markdown]
# # estudio valor objetivo

# %%
wide_obj_bs.info()
wide_obj_sp.info()

import numpy as np
import pandas as pd

# ========= 1) Unir ambos wide (objetivo) por claves =========
keys = ["Archivo", "n", "Capacidad", "%Desv"]
wide_obj = wide_obj_bs.merge(wide_obj_sp, on=keys, how="inner")

# ========= 2) Seleccionar columnas de objetivo y pasar a largo =========
cols_sp_obj = ["SP1", "SP2", "SP3", "SP4"]
cols_bs_obj = [c for c in wide_obj.columns if c.startswith("f_Gamma")]
cols_obj = cols_sp_obj + cols_bs_obj

long_obj = wide_obj.melt(
    id_vars=["Archivo", "n", "%Desv"],
    value_vars=cols_obj,
    var_name="Metodo",
    value_name="Valor"
)

# Normalizamos nombres de métodos Gamma (opcional estético)
long_obj["Metodo"] = long_obj["Metodo"].str.replace("^f_", "", regex=True)  # f_GammaX% -> GammaX%

# ========= 3) Promedio sobre %Desv por (Archivo, n, Metodo) =========
long_obj_avg = (
    long_obj
    .groupby(["Archivo", "n", "Metodo"], as_index=False)["Valor"]
    .mean()
)

# ========= 4) Estadísticos por (n, Metodo) =========
df_stats_obj = (
    long_obj_avg
    .groupby(["n", "Metodo"])["Valor"]
    .agg(
        Mediana="median",
        Q1=lambda x: np.percentile(x, 25),
        Q3=lambda x: np.percentile(x, 75),
        Media="mean",
        **{"Desv. típica": "std"}
    )
    .reset_index()
)

# ========= 5) Funciones auxiliares de tablas (igual que en tiempos) =========
def tabla_mediana(df, escala=1.0, dec=4, con_intervalo=False):
    df2 = df.copy()
    if con_intervalo:
        df2["Mediana [Q1, Q3]"] = df2.apply(
            lambda r: f"{r['Mediana']*escala:.{dec}f} [{r['Q1']*escala:.{dec}f}, {r['Q3']*escala:.{dec}f}]",
            axis=1
        )
        out = df2.pivot(index="n", columns="Metodo", values="Mediana [Q1, Q3]").reset_index()
    else:
        df2["Mediana"] = (df2["Mediana"]*escala).round(dec)
        out = df2.pivot(index="n", columns="Metodo", values="Mediana").reset_index()
    return out

def tabla_media(df, escala=1.0, dec=4, con_desv=False):
    df2 = df.copy()
    if con_desv:
        df2["Media ± Desv. típica"] = df2.apply(
            lambda r: f"{r['Media']*escala:.{dec}f} ± {r['Desv. típica']*escala:.{dec}f}",
            axis=1
        )
        out = df2.pivot(index="n", columns="Metodo", values="Media ± Desv. típica").reset_index()
    else:
        df2["Media"] = (df2["Media"]*escala).round(dec)
        out = df2.pivot(index="n", columns="Metodo", values="Media").reset_index()
    return out

# ========= 6) Generar tablas (sin escalado; ajusta escala/decimales si lo necesitas) =========
# (a) Mediana sola
tabla_obj_mediana = tabla_mediana(df_stats_obj, escala=1.0, dec=4, con_intervalo=False)

# (b) Media sola
tabla_obj_media = tabla_media(df_stats_obj, escala=1.0, dec=4, con_desv=False)

# (c) Mediana [Q1,Q3]
tabla_obj_mediana_iqr = tabla_mediana(df_stats_obj, escala=1.0, dec=4, con_intervalo=True)

# (d) Media ± Desv. típica
tabla_obj_media_desv = tabla_media(df_stats_obj, escala=1.0, dec=4, con_desv=True)

# ========= 7) (Opcional) ordenar columnas: SP1..SP4 y luego Gammas ascendentes =========
orden_cols = (["n"] + cols_sp_obj + sorted([c.replace("f_", "") for c in cols_bs_obj]))
for df_out in (tabla_obj_mediana, tabla_obj_media, tabla_obj_mediana_iqr, tabla_obj_media_desv):
    existing = [c for c in orden_cols if c in df_out.columns]
    df_out.sort_index(axis=1, inplace=True)  # orden alfabético por si acaso
    df_out = df_out.reindex(columns=(["n"] + [c for c in orden_cols[1:] if c in df_out.columns]))

display(tabla_obj_mediana)
display(tabla_obj_media)
display(tabla_obj_mediana_iqr)
display(tabla_obj_media_desv)

# %%
import numpy as np
import pandas as pd

# Claves comunes
keys = ["Archivo", "n", "Capacidad", "%Desv"]

# Unimos objetivos SP y RO (Bertsimas–Sim)
wide_obj_all = wide_obj_bs.merge(wide_obj_sp, on=keys, how="inner")

# Columnas de métodos
cols_gamma = [c for c in wide_obj_all.columns if c.startswith("f_Gamma")]
cols_sp    = ["SP1", "SP2", "SP3", "SP4"]

# ========= 1) Incrementos % respecto a SP1 =========
baseline_sp = wide_obj_all["SP1"].astype(float)

# Métodos a comparar vs SP1: SP2..SP4 + todos los Gamma
cols_vs_sp = ["SP2", "SP3", "SP4"] + cols_gamma

def pct_inc(col_vals, base):
    col_vals = col_vals.astype(float)
    # Evitar división por 0: si base==0 -> NaN
    return np.where(base != 0.0, (col_vals - base) / base, np.nan)

wide_obj_vs_sp = wide_obj_all[keys].copy()
# SP1 como 0%
wide_obj_vs_sp["SP1"] = 0.0
# Resto respecto a SP1
for c in cols_vs_sp:
    wide_obj_vs_sp[c] = pct_inc(wide_obj_all[c], baseline_sp)

# (Opcional) orden de columnas
wide_obj_vs_sp = wide_obj_vs_sp[keys + cols_sp + cols_gamma]

# ========= 2) Incrementos % respecto a nominal (Gamma = 0%) =========
baseline_nom = wide_obj_all["f_Gamma0%"].astype(float)

# Métodos a comparar vs Γ=0%: SP1..SP4 + Gamma5..Gamma100 (dejamos Gamma0 como 0)
cols_vs_nom = cols_sp + [c for c in cols_gamma if c != "f_Gamma0%"]

wide_obj_vs_nom = wide_obj_all[keys].copy()
# Gamma0% como 0%
wide_obj_vs_nom["f_Gamma0%"] = 0.0
# Resto respecto a Gamma0%
for c in cols_vs_nom:
    wide_obj_vs_nom[c] = pct_inc(wide_obj_all[c], baseline_nom)

# (Opcional) orden de columnas: claves + SP + Gammas (Gamma0 primero)
wide_obj_vs_nom = wide_obj_vs_nom[keys + cols_sp + ["f_Gamma0%"] + [c for c in cols_gamma if c != "f_Gamma0%"]]

# (Opcional) redondeo
wide_obj_vs_sp  = wide_obj_vs_sp.round(6)
wide_obj_vs_nom = wide_obj_vs_nom.round(6)

# Vistas rápidas
print("=== Incrementos % respecto a SP1 ===")
display(wide_obj_vs_sp.head())
print("\n=== Incrementos % respecto a Γ=0% (nominal) ===")
display(wide_obj_vs_nom.head())

# %%
wide_obj_vs_sp.to_excel("wide_obj_vs_sp.xlsx")
wide_obj_vs_nom.to_excel("wide_obj_vs_nom.xlsx")

files.download("wide_obj_vs_sp.xlsx")
files.download("wide_obj_vs_nom.xlsx")

# %%
df_nom_agg = (
    wide_obj_vs_nom
    .groupby(["n"], as_index=False)      # Agrupa por n
    .mean(numeric_only=True)            # Calcula la media de TODAS las columnas numéricas
)
df_nom_agg.to_excel("df_nom_agg_SOLO_NUM_ITEMS.xlsx")
files.download("df_nom_agg_SOLO_NUM_ITEMS.xlsx")

# %%
df_nom_agg_STD = (
    wide_obj_vs_nom
    .groupby(["n"], as_index=False)      # Agrupa por n
    .std(numeric_only=True)             # Calcula la desviación típica de TODAS las columnas numéricas
)

df_nom_agg_STD.to_excel("df_nom_agg_SOLO_NUM_ITEMS_STD.xlsx")
files.download("df_nom_agg_SOLO_NUM_ITEMS_STD.xlsx")

# %%
df_agg_incertidumbre = (
    wide_obj_vs_nom
    .groupby(["n", "%Desv"], as_index=False)
    .mean(numeric_only=True)
)

df_agg_incertidumbre_STD = (
    wide_obj_vs_nom
    .groupby(["n", "%Desv"], as_index=False)
    .std(numeric_only=True)
)

df_agg_incertidumbre.to_excel("df_agg_incertidumbre.xlsx")
df_agg_incertidumbre_STD.to_excel("df_agg_incertidumbre_STD.xlsx")
files.download("df_agg_incertidumbre.xlsx")
files.download("df_agg_incertidumbre_STD.xlsx")

# %% [markdown]
# # estudio de tiempo de computación

# %%
import numpy as np
import pandas as pd


wide_time = wide_time_bs.merge(
    wide_time_sp, on=["Archivo", "n", "Capacidad", "%Desv"],
    how="inner"
)
# --- Paso 1: Unir los dataframes (ya lo tienes) ---
# wide_time = wide_time_bs.merge(wide_time_sp, on=["Archivo", "n", "Capacidad", "%Desv"], how="inner")

# --- Paso 2: Seleccionar columnas de tiempo (mantenemos Archivo, n, %Desv) ---
cols_sp = ["tiempo_SP1", "tiempo_SP2", "tiempo_SP3", "tiempo_SP4"]
cols_bs = [c for c in wide_time.columns if c.startswith("tiempo_Gamma")]
cols_tiempo = cols_sp + cols_bs
base = wide_time[["Archivo", "n", "%Desv"] + cols_tiempo].copy()

# --- Paso 3: Formato largo conservando Archivo, n y %Desv ---
long_time = base.melt(
    id_vars=["Archivo", "n", "%Desv"],
    value_vars=cols_tiempo,
    var_name="Metodo",
    value_name="Tiempo"
)

# --- Paso 4: Promedio sobre %Desv por (Archivo, n, Metodo) ---
# (si hay varias filas para el mismo Archivo y n con %Desv=0.10/0.30/0.50, se promedia)
long_time_avg = (
    long_time
    .groupby(["Archivo", "n", "Metodo"], as_index=False)["Tiempo"]
    .mean()
)

# --- Paso 5: Estadísticos por (n, Metodo) usando las observaciones (Archivo) agregadas ---
def resumen(serie):
    med = serie.median()
    q1, q3 = np.percentile(serie, [25, 75])
    iqr = q3 - q1
    mean = serie.mean()
    std = serie.std(ddof=1)
    return pd.Series({
        "Median": med,
        "Median - IQR/2": med - iqr/2,
        "Median + IQR/2": med + iqr/2,
        "Mean": mean,
        "Mean - Std/2": mean - (std/2 if np.isfinite(std) else 0.0),
        "Mean + Std/2": mean + (std/2 if np.isfinite(std) else 0.0)
    })

df_stats_time = (
    long_time_avg
    .groupby(["n", "Metodo"])["Tiempo"]
    .apply(resumen)
    .reset_index()
)

# (Opcional) ordenar métodos: SP1..SP4 y luego Gamma ascendente
orden = ["tiempo_SP1","tiempo_SP2","tiempo_SP3","tiempo_SP4"] + sorted([c for c in cols_bs])
df_stats_time["Metodo"] = pd.Categorical(df_stats_time["Metodo"], categories=orden, ordered=True)
df_stats_time = df_stats_time.sort_values(["n","Metodo"]).reset_index(drop=True)

print(df_stats_time)
# Out:
#        n           Metodo         level_2    Tiempo
# 0     50       tiempo_SP1          Median  0.005933
# 1     50       tiempo_SP1  Median - IQR/2  0.003508
# 2     50       tiempo_SP1  Median + IQR/2  0.008358
# 3     50       tiempo_SP1            Mean  0.010131
# 4     50       tiempo_SP1    Mean - Std/2  0.004250
# ..   ...              ...             ...       ...
# 259  500  tiempo_Gamma75%  Median - IQR/2  0.006143
# 260  500  tiempo_Gamma75%  Median + IQR/2  0.006814
# 261  500  tiempo_Gamma75%            Mean  0.006667
# 262  500  tiempo_Gamma75%    Mean - Std/2  0.006276
# 263  500  tiempo_Gamma75%    Mean + Std/2  0.007057
#
# [264 rows x 4 columns]

# %%
import numpy as np
import pandas as pd

# --- 1) Unir (asumo que ya tienes wide_time_bs y wide_time_sp) ---
wide_time = wide_time_bs.merge(
    wide_time_sp, on=["Archivo", "n", "Capacidad", "%Desv"], how="inner"
)

# --- 2) Seleccionar columnas de tiempo y pasar a largo ---
cols_sp = ["tiempo_SP1", "tiempo_SP2", "tiempo_SP3", "tiempo_SP4"]
cols_bs = [c for c in wide_time.columns if c.startswith("tiempo_Gamma")]
cols_tiempo = cols_sp + cols_bs

long_time = wide_time.melt(
    id_vars=["Archivo", "n", "%Desv"],
    value_vars=cols_tiempo,
    var_name="Metodo",
    value_name="Tiempo"
)

# --- 3) Promediar sobre %Desv por (Archivo, n, Metodo) ---
long_time_avg = (
    long_time
    .groupby(["Archivo", "n", "Metodo"], as_index=False)["Tiempo"]
    .mean()
)

# --- 4) Estadísticos por (n, Metodo) ---
df_stats = (
    long_time_avg
    .groupby(["n", "Metodo"])["Tiempo"]
    .agg(
        Mediana="median",
        Q1=lambda x: np.percentile(x, 25),
        Q3=lambda x: np.percentile(x, 75),
        Media="mean",
        **{"Desv. típica": "std"}
    )
    .reset_index()
)

# --- Funciones auxiliares ---
def tabla_mediana(df, escala=1.0, dec=4, con_intervalo=False):
    df2 = df.copy()
    if con_intervalo:
        df2["Mediana [Q1, Q3]"] = df2.apply(
            lambda r: f"{r['Mediana']*escala:.{dec}f} [{r['Q1']*escala:.{dec}f}, {r['Q3']*escala:.{dec}f}]",
            axis=1
        )
        out = df2.pivot(index="n", columns="Metodo", values="Mediana [Q1, Q3]").reset_index()
    else:
        df2["Mediana"] = (df2["Mediana"]*escala).round(dec)
        out = df2.pivot(index="n", columns="Metodo", values="Mediana").reset_index()
    return out

def tabla_media(df, escala=1.0, dec=4, con_desv=False):
    df2 = df.copy()
    if con_desv:
        df2["Media ± Desv. típica"] = df2.apply(
            lambda r: f"{r['Media']*escala:.{dec}f} ± {r['Desv. típica']*escala:.{dec}f}",
            axis=1
        )
        out = df2.pivot(index="n", columns="Metodo", values="Media ± Desv. típica").reset_index()
    else:
        df2["Media"] = (df2["Media"]*escala).round(dec)
        out = df2.pivot(index="n", columns="Metodo", values="Media").reset_index()
    return out

# --- 5) Generar tablas ---
# (a) Mediana sola en ms
tabla_mediana_ms = tabla_mediana(df_stats, escala=1e3, dec=1, con_intervalo=False)

# (b) Media sola en segundos
tabla_media_s = tabla_media(df_stats, escala=1.0, dec=4, con_desv=False)

# (c) Mediana [Q1,Q3] en ms
tabla_mediana_iqr_ms = tabla_mediana(df_stats, escala=1e3, dec=1, con_intervalo=True)

# (d) Media ± Desv. típica en ms
tabla_media_desv_ms = tabla_media(df_stats, escala=1e3, dec=1, con_desv=True)

# (e) Media ± Desv. típica en segundos
tabla_media_desv_s = tabla_media(df_stats, escala=1.0, dec=4, con_desv=True)

# --- 6) Mostrar ---
display(tabla_mediana_ms)
display(tabla_media_s)
display(tabla_mediana_iqr_ms)
display(tabla_media_desv_ms)
display(tabla_media_desv_s)
# Out:
# Metodo    n  tiempo_Gamma0%  tiempo_Gamma10%  tiempo_Gamma100%  \
# 0        50             1.0              1.1               1.2
# 1       100             1.8              2.0               2.4
# 2       200             3.5              3.3               4.1
# 3       500             3.9              6.0               6.2
#
# Metodo  tiempo_Gamma25%  tiempo_Gamma5%  tiempo_Gamma50%  tiempo_Gamma75%  \
# 0                   1.2             1.1              1.3              1.1
# 1                   2.2             1.8              2.4              2.6
# 2                   4.1             3.2              4.5              3.9
# 3                   7.9             4.9              9.1              6.5
#
# Metodo  tiempo_SP1  tiempo_SP2  tiempo_SP3  tiempo_SP4
# 0              5.9        26.6       197.1      1463.3
# 1              7.6        43.7       340.2      3964.5
# 2             13.9        97.0       982.3     13842.0
# 3             30.8       292.3      4890.9     90811.1
# Metodo    n  tiempo_Gamma0%  tiempo_Gamma10%  tiempo_Gamma100%  \
# 0        50          0.0010           0.0012            0.0013
# 1       100          0.0018           0.0020            0.0023
# 2       200          0.0037           0.0037            0.0041
# 3       500          0.0043           0.0062            0.0064
#
# Metodo  tiempo_Gamma25%  tiempo_Gamma5%  tiempo_Gamma50%  tiempo_Gamma75%  \
# 0                0.0012          0.0012           0.0015           0.0012
# 1                0.0023          0.0020           0.0027           0.0026
# 2                0.0041          0.0035           0.0050           0.0042
# 3                0.0082          0.0051           0.0092           0.0067
#
# Metodo  tiempo_SP1  tiempo_SP2  tiempo_SP3  tiempo_SP4
# 0           0.0101      0.0311      0.2140      1.6485
# 1           0.0077      0.0439      0.3623      4.0359
# 2           0.0143      0.1003      1.0343     13.9459
# 3           0.0322      0.2986      4.9292     90.3874
# Metodo    n  tiempo_Gamma0% tiempo_Gamma10% tiempo_Gamma100% tiempo_Gamma25%  \
# 0        50  1.0 [0.9, 1.1]  1.1 [1.0, 1.2]   1.2 [1.1, 1.3]  1.2 [1.1, 1.3]
# 1       100  1.8 [1.6, 2.0]  2.0 [1.7, 2.1]   2.4 [2.1, 2.6]  2.2 [2.1, 2.5]
# 2       200  3.5 [2.9, 3.9]  3.3 [3.0, 4.0]   4.1 [3.7, 4.3]  4.1 [3.8, 4.2]
# 3       500  3.9 [3.7, 4.2]  6.0 [5.5, 6.6]   6.2 [5.8, 6.9]  7.9 [7.0, 8.9]
#
# Metodo  tiempo_Gamma5% tiempo_Gamma50% tiempo_Gamma75%         tiempo_SP1  \
# 0       1.1 [1.0, 1.2]  1.3 [1.2, 1.5]  1.1 [1.1, 1.2]     5.9 [4.9, 9.8]
# 1       1.8 [1.7, 2.2]  2.4 [2.3, 2.8]  2.6 [2.1, 2.8]     7.6 [6.9, 8.6]
# 2       3.2 [2.9, 3.6]  4.5 [4.3, 5.3]  3.9 [3.7, 4.1]  13.9 [12.8, 15.8]
# 3       4.9 [4.7, 5.3]  9.1 [8.7, 9.5]  6.5 [6.2, 6.9]  30.8 [29.9, 35.7]
#
# Metodo            tiempo_SP2               tiempo_SP3  \
# 0          26.6 [25.4, 34.6]     197.1 [159.4, 243.0]
# 1          43.7 [38.8, 48.8]     340.2 [332.8, 390.0]
# 2         97.0 [83.5, 112.0]    982.3 [901.4, 1094.6]
# 3       292.3 [274.5, 317.5]  4890.9 [4858.8, 5104.0]
#
# Metodo                  tiempo_SP4
# 0          1463.3 [1275.4, 1936.2]
# 1          3964.5 [3701.3, 4307.0]
# 2       13842.0 [13563.6, 14033.5]
# 3       90811.1 [87859.3, 91133.8]
# Metodo    n tiempo_Gamma0% tiempo_Gamma10% tiempo_Gamma100% tiempo_Gamma25%  \
# 0        50      1.0 ± 0.2       1.2 ± 0.4        1.3 ± 0.2       1.2 ± 0.2
# 1       100      1.8 ± 0.4       2.0 ± 0.5        2.3 ± 0.3       2.3 ± 0.4
# 2       200      3.7 ± 1.4       3.7 ± 1.0        4.1 ± 0.5       4.1 ± 0.8
# 3       500      4.3 ± 1.4       6.2 ± 1.2        6.4 ± 0.8       8.2 ± 1.5
#
# Metodo tiempo_Gamma5% tiempo_Gamma50% tiempo_Gamma75%   tiempo_SP1  \
# 0           1.2 ± 0.2       1.5 ± 0.5       1.2 ± 0.2  10.1 ± 11.8
# 1           2.0 ± 0.4       2.7 ± 0.8       2.6 ± 0.8    7.7 ± 1.0
# 2           3.5 ± 1.2       5.0 ± 1.1       4.2 ± 1.2   14.3 ± 1.8
# 3           5.1 ± 0.6       9.2 ± 1.2       6.7 ± 0.8   32.2 ± 3.3
#
# Metodo    tiempo_SP2      tiempo_SP3        tiempo_SP4
# 0         31.1 ± 8.0    214.0 ± 58.5    1648.5 ± 453.1
# 1         43.9 ± 5.9    362.3 ± 45.3    4035.9 ± 420.3
# 2       100.3 ± 17.6  1034.3 ± 188.7   13945.9 ± 523.7
# 3       298.6 ± 34.7  4929.2 ± 260.8  90387.4 ± 4595.9
# Metodo    n   tiempo_Gamma0%  tiempo_Gamma10% tiempo_Gamma100%  \
# 0        50  0.0010 ± 0.0002  0.0012 ± 0.0004  0.0013 ± 0.0002
# 1       100  0.0018 ± 0.0004  0.0020 ± 0.0005  0.0023 ± 0.0003
# 2       200  0.0037 ± 0.0014  0.0037 ± 0.0010  0.0041 ± 0.0005
# 3       500  0.0043 ± 0.0014  0.0062 ± 0.0012  0.0064 ± 0.0008
#
# Metodo  tiempo_Gamma25%   tiempo_Gamma5%  tiempo_Gamma50%  tiempo_Gamma75%  \
# 0       0.0012 ± 0.0002  0.0012 ± 0.0002  0.0015 ± 0.0005  0.0012 ± 0.0002
# 1       0.0023 ± 0.0004  0.0020 ± 0.0004  0.0027 ± 0.0008  0.0026 ± 0.0008
# 2       0.0041 ± 0.0008  0.0035 ± 0.0012  0.0050 ± 0.0011  0.0042 ± 0.0012
# 3       0.0082 ± 0.0015  0.0051 ± 0.0006  0.0092 ± 0.0012  0.0067 ± 0.0008
#
# Metodo       tiempo_SP1       tiempo_SP2       tiempo_SP3        tiempo_SP4
# 0       0.0101 ± 0.0118  0.0311 ± 0.0080  0.2140 ± 0.0585   1.6485 ± 0.4531
# 1       0.0077 ± 0.0010  0.0439 ± 0.0059  0.3623 ± 0.0453   4.0359 ± 0.4203
# 2       0.0143 ± 0.0018  0.1003 ± 0.0176  1.0343 ± 0.1887  13.9459 ± 0.5237
# 3       0.0322 ± 0.0033  0.2986 ± 0.0347  4.9292 ± 0.2608  90.3874 ± 4.5959

# %%
import pandas as pd
from google.colab import files

# Diccionario con nombre de hoja y DataFrame
tablas = {
    "Mediana_ms": tabla_mediana_ms,
    "Media_s": tabla_media_s,
    "Mediana_IQR_ms": tabla_mediana_iqr_ms,
    "Media_Desv_ms": tabla_media_desv_ms,
    "Media_Desv_s": tabla_media_desv_s,
}

# Guardar todas las tablas en un Excel con una hoja cada una
with pd.ExcelWriter("anexo_tablas.xlsx") as writer:
    for nombre, df in tablas.items():
        df.to_excel(writer, sheet_name=nombre, index=False)

# Descargar el archivo
files.download("anexo_tablas.xlsx")

# %%
df_stats_time_med.to_excel("df_stats_time_med.xlsx", index=False)
df_stats_time_mean.to_excel("df_stats_time_mean.xlsx", index=False)
files.download("df_stats_time_med.xlsx")
files.download("df_stats_time_mean.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1365506374.py in <cell line: 0>()
# ----> 1 df_stats_time_med.to_excel("df_stats_time_med.xlsx", index=False)
#       2 df_stats_time_mean.to_excel("df_stats_time_mean.xlsx", index=False)
#       3 files.download("df_stats_time_med.xlsx")
#       4 files.download("df_stats_time_mean.xlsx")
#
# NameError: name 'df_stats_time_med' is not defined

# %%
from google.colab import files

df_stats_time.to_excel("df_stats_time.xlsx", index=False)
files.download("df_stats_time.xlsx")
wide_time.to_excel("wide_time.xlsx", index=False)
files.download("wide_time.xlsx")

# %%
from scipy.stats import shapiro
import pandas as pd

# Aplicamos test de Shapiro-Wilk por (n, Metodo)
def test_normalidad(grupo):
    stat, p = shapiro(grupo["Tiempo"])
    return pd.Series({
        "W-statistic": stat,
        "p-value": p,
        "Normal?": p > 0.05  # H0: los datos provienen de una dist. normal
    })

df_normalidad = long_time.groupby(["n", "Metodo"]).apply(test_normalidad).reset_index()

print(df_normalidad)

# %%
for n, _ in wide_time.groupby("n")
cols_sp = ["tiempo_SP1", "tiempo_SP2", "tiempo_SP3", "tiempo_SP4"]
cols_bs = [c for c in wide_time.columns if c.startswith("tiempo_Gamma")]
cols = cols_sp + cols_bs

temp = wide_time[cols]
#display(temp)


long_time = temp.melt(var_name="Metodo", value_name="Tiempo")
#display(long_time)


# # --- Paso 4: Calcular estadísticas ---
def resumen(grupo):
    med = grupo.median()
    q1, q3 = grupo.quantile([0.25, 0.75])
    iqr = q3 - q1
    mean = grupo.mean()
    std = grupo.std()
    return pd.Series({
        "Median": med,
        "Median - IQR/2": med - iqr/2,
        "Median + IQR/2": med + iqr/2,
        "Mean": mean,
        "Mean - Std/2": mean - std/2,
        "Mean + Std/2": mean + std/2
    })

df_stats_time = long_time.groupby("Metodo")["Tiempo"].apply(resumen).reset_index()

print(df_stats_time)

# %%
display(df_stats_time)

# %% [markdown]
# # ARCHIVED

# %%
# --- Guardar a Excel (dos hojas) y descargar si estás en Colab ---
# out_name = "Resultados_SP1_SP4_n50_100_200.xlsx"
# with pd.ExcelWriter(out_name, engine="xlsxwriter") as writer:
#     df_res.to_excel(writer, sheet_name="long", index=False)
#     wide_sp.to_excel(writer, sheet_name="wide", index=False)

# if IN_COLAB:
#     files.download(out_name)
# else:
#     print(f"\n[Info] Archivo guardado: {out_name} (ejecuta en Colab para descargar automáticamente).")

# # --- Guardar a Excel (dos hojas) y descargar si estás en Colab ---
# out_name = "Resultados_SP1_SP4_n50_100_200.xlsx"
# with pd.ExcelWriter(out_name, engine="xlsxwriter") as writer:
#     df_res.to_excel(writer, sheet_name="long", index=False)
#     wide_sp.to_excel(writer, sheet_name="wide", index=False)

# if IN_COLAB:
#     files.download(out_name)
# else:
#     print(f"\n[Info] Archivo guardado: {out_name} (ejecuta en Colab para descargar automáticamente).")






# import numpy as np
# # PRUEBAS CON SOLO 1 INSTANCIA
# # --- Selecciona una instancia de df_kplib ---
# i = 6  # <-- cambia el indice si quieres otra fila
# u   = df_kplib.at[i, "Utilidades"]
# w   = df_kplib.at[i, "Pesos"]
# cap = float(df_kplib.at[i, "Capacidad"])
# arc = df_kplib.at[i, "Archivo"] if "Archivo" in df_kplib.columns else f"idx_{i}"

# bar_c, pesos = np.array(u, float), np.array(w, float)
# assert bar_c.size == pesos.size, "Utilidades y pesos deben tener la misma longitud"

# # --- Parametros de incertidumbre y muestreo ---
# pct_desviacion, seed, n_smpl = 0.50, 123, 8  # ajusta si quieres

# print(f"Instancia: {arc} | n={bar_c.size} | cap={cap} | pct={pct_desviacion} | n_smpl={n_smpl} | seed={seed}")

# for t in (1, 2, 3, 4):
#     print("\n" + "-"*60)
#     print(f"Resolviendo SP{t} ...")
#     sol = solve_sp(bar_c, pesos, cap, pct_desviacion, t=t, n_smpl=n_smpl, seed=seed, verbose=True)
#     print(f"Resumen SP{t}: status={sol['status']} | obj={sol['objective']:.4f} | vars={sol['n_vars']} | cons={sol['n_constrs']}")
